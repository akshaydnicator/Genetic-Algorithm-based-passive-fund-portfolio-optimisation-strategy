# %%
# %%time
# Import libraries and load monthly stock price data

import numpy as np
import pandas as pd
import math
rf= 0.000195179701757642


##Mean portfolio return = Mean Return * Fractions of Total Capital (Chromosome). 
# Risk-free rate = 0.05 (assumption) 
# Standard deviation of portfolio return = (chromosome * Standard deviation)**2 + Covariance * Respective weights in chromosome.
def mean_portfolio_return(child):
    return np.sum(np.multiply(child,mean_hist_return))
def var_portfolio_return(child):
    part_1 = np.sum(np.multiply(child,sd_hist_return)**2)
    temp_lst=[]
    for i in range(50):
        for j in range(50):
            temp=cov_hist_return.iloc[i][j] * child[i] * child[j]
            temp_lst.append(temp)
    part_2=np.sum(temp_lst)
    return part_1+part_2

# Chromosome: Set of genes i.e. fractions of total capital assigned to each asset
def chromosome(n):
    ''' Generates set of random numbers whose sum is equal to 1
        Input: Number of stocks.
        Output: Array of random numbers'''
    ch = np.random.rand(n)
    return ch/sum(ch)

## Fitness function : The Sharpe ratio, S = (µ − r)/σ
## Maximize return, minimize risk
def fitness_fuction(child):
    ''' This will return the Sharpe ratio for a particular portfolio.
        Input: A child/chromosome (1D Array)
        Output: Sharpe Ratio value (Scalar)'''
    return (mean_portfolio_return(child)-rf)/np.sqrt(var_portfolio_return(child))

def Select_elite_population(population, frac=0.3):
    ''' Select elite population from the total population based on fitness function values.
        Input: Population and fraction of population to be considered as elite.
        Output: Elite population.'''
    population = sorted(population,key = lambda x: fitness_fuction(x),reverse=True)
    percentage_elite_idx = int(np.floor(len(population)* frac))
    return population[:percentage_elite_idx]

def mutation(parent):
    ''' Randomy choosen elements of a chromosome are swapped
        Input: Parent
        Output: Offspring (1D Array)'''
    child=parent.copy()
    n=np.random.choice(range(50),2)
    while (n[0]==n[1]):
        n=np.random.choice(range(50),2)
    child[n[0]],child[n[1]]=child[n[1]],child[n[0]]
    return child

def Heuristic_crossover(parent1,parent2):
    ''' The oﬀsprings are created according to the equation:
            Off_spring A = Best Parent  + β ∗ ( Best Parent − Worst Parent)
            Off_spring B = Worst Parent - β ∗ ( Best Parent − Worst Parent)
                Where β is a random number between 0 and 1.
        Input: 2 Parents
        Output: 2 Children (1d Array)'''
    ff1=fitness_fuction(parent1)
    ff2=fitness_fuction(parent2)
    diff=parent1 - parent2
    beta=np.random.rand()
    if ff1>ff2:
        child1=parent1 + beta * diff
        child2=parent2 - beta * diff
    else:
        child2=parent1 + beta * diff
        child1=parent2 - beta * diff
    return child1,child2

def Arithmetic_crossover(parent1,parent2):
    ''' The oﬀsprings are created according to the equation:
            Off spring A = α ∗ Parent1 + (1 −α) ∗ Parent2
            Off spring B = (1 −α) ∗ Parent1 + α ∗ Parent2
            
                Where α is a random number between 0 and 1.
        Input: 2 Parents
        Output: 2 Children (1d Array)'''
    alpha = np.random.rand()
    child1 = alpha * parent1 + (1-alpha) * parent2
    child2 = (1-alpha) * parent1 + alpha * parent2
    return child1,child2

def next_generation(pop_size,elite,crossover=Arithmetic_crossover):
    ''' Generates new population from elite population with mutation probability as 0.4 and crossover as 0.6. 
        Over the final stages, mutation probability is decreased to 0.1.
        Input: Population Size and elite population.
        Output: Next generation population (2D Array).'''
    new_population=[]
    elite_range=range(len(elite))
    #print(elite_range)
    while len(new_population) < pop_size:
        if len(new_population) > 2*pop_size/3: # In the final stages mutation frequency is decreased.
            mutate_or_crossover = np.random.choice([0, 1], p=[0.6, 0.4])
        else:
            mutate_or_crossover = np.random.choice([0, 1], p=[0.4, 0.6])
        #print(mutate_or_crossover)
        if mutate_or_crossover:
            indx=np.random.choice(elite_range)
            new_population.append(mutation(elite[indx]))
            #print('Mutation!')
        else:
            p1_idx,p2_idx=np.random.choice(elite_range,2)
            c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            chk=0
            for gene in range(50):
                if c1[gene]<0:
                    chk+=1
                else:
                    chk+=0
            if chk>0:
                p1_idx,p2_idx=np.random.choice(elite_range,2)
                c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            
            new_population.extend([c1,c2])
            #print('Crossover!')    
    return new_population


hist_stock_returns = pd.read_csv('Nifty50returnsJuly2018-Jun2021.csv')
hist_stock_returns['date'] = pd.to_datetime(hist_stock_returns['date'], format='%d-%m-%Y')
hist_stock_returns.set_index('date',inplace=True)

mean_hist_return=hist_stock_returns.mean()
#print(mean_hist_return)
sd_hist_return=hist_stock_returns.std()
#print(sd_hist_return)
cov_hist_return=hist_stock_returns.cov()
#print(cov_hist_return)
for i in range(50):
    cov_hist_return.iloc[i][i]=0
#print(cov_hist_return)

    
## Determine the Optimum portfolio using Arithmetic Crossover  

n=50 # Number of stocks = 6
pop_size=250 # initial population = 100

# Initial population
population = np.array([chromosome(n) for _ in range(pop_size)])

# Get initial elite population
elite = Select_elite_population(population)

iteration=0 
Expected_returns=10
Expected_risk=15

plotData = {
    "expReturns": [],
    "expRisk": [],
    "SharpeRatio": [] 
}

while (Expected_returns < 30 or Expected_risk > 10) and iteration <= 300:
        
    population = next_generation(250,elite)
    elite = Select_elite_population(population)
    
    Expected_returns=(((1+mean_portfolio_return(elite[0]))**250)-1)*100
    Expected_risk=math.sqrt(var_portfolio_return(elite[0]))*math.sqrt(250)*100
    SR = (Expected_returns-5)/Expected_risk
    
    print('Iteration:',iteration)    
    print('Expected returns of {} with risk of {} and SR = {}\n'.format(round(Expected_returns,ndigits=3),round(Expected_risk,ndigits=3),round(SR,ndigits=3)))
    plotData['expReturns'].extend([Expected_returns])
    plotData['expRisk'].extend([Expected_risk])
    plotData['SharpeRatio'].extend([SR])
    
    iteration+=1

print('\n\n=====================================================\nPortfolio of stocks after all the iterations:\n')
[print(hist_stock_returns.columns[i],':',elite[0][i]) for i in list(range(50))]

print('\nExpected returns of {} with risk of {} and Sharpe Ratio of {}\n'.format(round(Expected_returns,ndigits=3),round(Expected_risk,ndigits=3),round(SR,ndigits=3)))

companies = []
wts = []
for i in list(range(50)):
    companies = companies + [hist_stock_returns.columns[i]]
    wts = wts + [elite[0][i]]

wtDf = pd.DataFrame(columns=['Company','Weight'])
wtDf.Company = companies
wtDf.Weight = wts
wtDf.to_csv('OptimizedWeightsJul2021-Dec2021.csv',index=False)
# Out:
# Iteration: 0
# Expected returns of 24.174 with risk of 21.554 and SR = 0.89
#
# Iteration: 1
# Expected returns of 23.721 with risk of 20.805 and SR = 0.9
#
# Iteration: 2
# Expected returns of 24.654 with risk of 21.69 and SR = 0.906
#
# Iteration: 3
# Expected returns of 25.703 with risk of 22.01 and SR = 0.941
#
# Iteration: 4
# Expected returns of 25.699 with risk of 22.008 and SR = 0.941
#
# Iteration: 5
# Expected returns of 25.705 with risk of 22.015 and SR = 0.94
#
# Iteration: 6
# Expected returns of 25.483 with risk of 21.818 and SR = 0.939
#
# Iteration: 7
# Expected returns of 26.041 with risk of 21.863 and SR = 0.962
#
# Iteration: 8
# Expected returns of 26.213 with risk of 21.526 and SR = 0.985
#
# Iteration: 9
# Expected returns of 26.462 with risk of 21.67 and SR = 0.99
#
# Iteration: 10
# Expected returns of 26.328 with risk of 21.548 and SR = 0.99
#
# Iteration: 11
# Expected returns of 26.217 with risk of 21.523 and SR = 0.986
#
# Iteration: 12
# Expected returns of 26.483 with risk of 21.338 and SR = 1.007
#
# Iteration: 13
# Expected returns of 26.639 with risk of 21.37 and SR = 1.013
#
# Iteration: 14
# Expected returns of 26.58 with risk of 21.281 and SR = 1.014
#
# Iteration: 15
# Expected returns of 27.314 with risk of 21.821 and SR = 1.023
#
# Iteration: 16
# Expected returns of 27.351 with risk of 21.633 and SR = 1.033
#
# Iteration: 17
# Expected returns of 27.647 with risk of 21.772 and SR = 1.04
#
# Iteration: 18
# Expected returns of 27.65 with risk of 21.914 and SR = 1.034
#
# Iteration: 19
# Expected returns of 27.391 with risk of 21.554 and SR = 1.039
#
# Iteration: 20
# Expected returns of 27.117 with risk of 21.203 and SR = 1.043
#
# Iteration: 21
# Expected returns of 27.529 with risk of 21.566 and SR = 1.045
#
# Iteration: 22
# Expected returns of 28.052 with risk of 21.897 and SR = 1.053
#
# Iteration: 23
# Expected returns of 27.832 with risk of 21.517 and SR = 1.061
#
# Iteration: 24
# Expected returns of 27.921 with risk of 21.57 and SR = 1.063
#
# Iteration: 25
# Expected returns of 27.762 with risk of 21.416 and SR = 1.063
#
# Iteration: 26
# Expected returns of 28.173 with risk of 21.597 and SR = 1.073
#
# Iteration: 27
# Expected returns of 28.142 with risk of 21.504 and SR = 1.076
#
# Iteration: 28
# Expected returns of 28.239 with risk of 21.552 and SR = 1.078
#
# Iteration: 29
# Expected returns of 28.239 with risk of 21.552 and SR = 1.078
#
# Iteration: 30
# Expected returns of 28.241 with risk of 21.445 and SR = 1.084
#
# Iteration: 31
# Expected returns of 28.25 with risk of 21.442 and SR = 1.084
#
# Iteration: 32
# Expected returns of 28.712 with risk of 21.724 and SR = 1.092
#
# Iteration: 33
# Expected returns of 28.419 with risk of 21.404 and SR = 1.094
#
# Iteration: 34
# Expected returns of 28.2 with risk of 21.275 and SR = 1.09
#
# Iteration: 35
# Expected returns of 28.7 with risk of 21.606 and SR = 1.097
#
# Iteration: 36
# Expected returns of 28.716 with risk of 21.587 and SR = 1.099
#
# Iteration: 37
# Expected returns of 28.564 with risk of 21.503 and SR = 1.096
#
# Iteration: 38
# Expected returns of 28.676 with risk of 21.543 and SR = 1.099
#
# Iteration: 39
# Expected returns of 28.616 with risk of 21.483 and SR = 1.099
#
# Iteration: 40
# Expected returns of 28.722 with risk of 21.504 and SR = 1.103
#
# Iteration: 41
# Expected returns of 28.692 with risk of 21.504 and SR = 1.102
#
# Iteration: 42
# Expected returns of 28.302 with risk of 21.162 and SR = 1.101
#
# Iteration: 43
# Expected returns of 28.447 with risk of 21.209 and SR = 1.106
#
# Iteration: 44
# Expected returns of 28.498 with risk of 21.281 and SR = 1.104
#
# Iteration: 45
# Expected returns of 28.922 with risk of 21.573 and SR = 1.109
#
# Iteration: 46
# Expected returns of 28.853 with risk of 21.501 and SR = 1.109
#
# Iteration: 47
# Expected returns of 28.929 with risk of 21.499 and SR = 1.113
#
# Iteration: 48
# Expected returns of 28.935 with risk of 21.472 and SR = 1.115
#
# Iteration: 49
# Expected returns of 28.942 with risk of 21.467 and SR = 1.115
#
# Iteration: 50
# Expected returns of 28.853 with risk of 21.437 and SR = 1.113
#
# Iteration: 51
# Expected returns of 28.876 with risk of 21.419 and SR = 1.115
#
# Iteration: 52
# Expected returns of 28.863 with risk of 21.416 and SR = 1.114
#
# Iteration: 53
# Expected returns of 28.86 with risk of 21.415 and SR = 1.114
#
# Iteration: 54
# Expected returns of 28.59 with risk of 21.146 and SR = 1.116
#
# Iteration: 55
# Expected returns of 28.681 with risk of 21.235 and SR = 1.115
#
# Iteration: 56
# Expected returns of 28.705 with risk of 21.266 and SR = 1.115
#
# Iteration: 57
# Expected returns of 28.937 with risk of 21.395 and SR = 1.119
#
# Iteration: 58
# Expected returns of 28.94 with risk of 21.394 and SR = 1.119
#
# Iteration: 59
# Expected returns of 28.825 with risk of 21.248 and SR = 1.121
#
# Iteration: 60
# Expected returns of 28.824 with risk of 21.256 and SR = 1.121
#
# Iteration: 61
# Expected returns of 28.824 with risk of 21.272 and SR = 1.12
#
# Iteration: 62
# Expected returns of 28.888 with risk of 21.296 and SR = 1.122
#
# Iteration: 63
# Expected returns of 28.881 with risk of 21.287 and SR = 1.122
#
# Iteration: 64
# Expected returns of 28.876 with risk of 21.29 and SR = 1.121
#
# Iteration: 65
# Expected returns of 28.958 with risk of 21.352 and SR = 1.122
#
# Iteration: 66
# Expected returns of 28.916 with risk of 21.324 and SR = 1.122
#
# Iteration: 67
# Expected returns of 28.944 with risk of 21.33 and SR = 1.123
#
# Iteration: 68
# Expected returns of 28.903 with risk of 21.241 and SR = 1.125
#
# Iteration: 69
# Expected returns of 28.779 with risk of 21.142 and SR = 1.125
#
# Iteration: 70
# Expected returns of 28.908 with risk of 21.244 and SR = 1.125
#
# Iteration: 71
# Expected returns of 28.889 with risk of 21.237 and SR = 1.125
#
# Iteration: 72
# Expected returns of 28.85 with risk of 21.204 and SR = 1.125
#
# Iteration: 73
# Expected returns of 28.849 with risk of 21.205 and SR = 1.125
#
# Iteration: 74
# Expected returns of 28.855 with risk of 21.21 and SR = 1.125
#
# Iteration: 75
# Expected returns of 28.858 with risk of 21.174 and SR = 1.127
#
# Iteration: 76
# Expected returns of 28.857 with risk of 21.174 and SR = 1.127
#
# Iteration: 77
# Expected returns of 28.83 with risk of 21.148 and SR = 1.127
#
# Iteration: 78
# Expected returns of 28.861 with risk of 21.171 and SR = 1.127
#
# Iteration: 79
# Expected returns of 28.854 with risk of 21.173 and SR = 1.127
#
# Iteration: 80
# Expected returns of 28.893 with risk of 21.201 and SR = 1.127
#
# Iteration: 81
# Expected returns of 28.936 with risk of 21.241 and SR = 1.127
#
# Iteration: 82
# Expected returns of 28.959 with risk of 21.242 and SR = 1.128
#
# Iteration: 83
# Expected returns of 28.948 with risk of 21.235 and SR = 1.128
#
# Iteration: 84
# Expected returns of 28.915 with risk of 21.202 and SR = 1.128
#
# Iteration: 85
# Expected returns of 28.902 with risk of 21.19 and SR = 1.128
#
# Iteration: 86
# Expected returns of 28.901 with risk of 21.186 and SR = 1.128
#
# Iteration: 87
# Expected returns of 28.901 with risk of 21.187 and SR = 1.128
#
# Iteration: 88
# Expected returns of 28.974 with risk of 21.238 and SR = 1.129
#
# Iteration: 89
# Expected returns of 28.971 with risk of 21.237 and SR = 1.129
#
# Iteration: 90
# Expected returns of 28.975 with risk of 21.239 and SR = 1.129
#
# Iteration: 91
# Expected returns of 28.846 with risk of 21.129 and SR = 1.129
#
# Iteration: 92
# Expected returns of 28.951 with risk of 21.208 and SR = 1.129
#
# Iteration: 93
# Expected returns of 28.944 with risk of 21.204 and SR = 1.129
#
# Iteration: 94
# Expected returns of 28.911 with risk of 21.18 and SR = 1.129
#
# Iteration: 95
# Expected returns of 28.959 with risk of 21.211 and SR = 1.13
#
# Iteration: 96
# Expected returns of 28.959 with risk of 21.213 and SR = 1.129
#
# Iteration: 97
# Expected returns of 28.953 with risk of 21.209 and SR = 1.129
#
# Iteration: 98
# Expected returns of 28.924 with risk of 21.184 and SR = 1.129
#
# Iteration: 99
# Expected returns of 28.918 with risk of 21.18 and SR = 1.129
#
# Iteration: 100
# Expected returns of 28.88 with risk of 21.147 and SR = 1.129
#
# Iteration: 101
# Expected returns of 28.832 with risk of 21.107 and SR = 1.129
#
# Iteration: 102
# Expected returns of 28.887 with risk of 21.152 and SR = 1.129
#
# Iteration: 103
# Expected returns of 28.884 with risk of 21.147 and SR = 1.129
#
# Iteration: 104
# Expected returns of 28.904 with risk of 21.165 and SR = 1.129
#
# Iteration: 105
# Expected returns of 28.873 with risk of 21.136 and SR = 1.13
#
# Iteration: 106
# Expected returns of 28.884 with risk of 21.145 and SR = 1.13
# Iteration: 107
# Expected returns of 28.884 with risk of 21.145 and SR = 1.13
#
# Iteration: 108
# Expected returns of 28.832 with risk of 21.103 and SR = 1.129
#
# Iteration: 109
# Expected returns of 28.834 with risk of 21.104 and SR = 1.129
#
# Iteration: 110
# Expected returns of 28.843 with risk of 21.112 and SR = 1.129
#
# Iteration: 111
# Expected returns of 28.857 with risk of 21.118 and SR = 1.13
#
# Iteration: 112
# Expected returns of 28.822 with risk of 21.085 and SR = 1.13
#
# Iteration: 113
# Expected returns of 28.832 with risk of 21.096 and SR = 1.13
#
# Iteration: 114
# Expected returns of 28.864 with risk of 21.121 and SR = 1.13
#
# Iteration: 115
# Expected returns of 28.866 with risk of 21.123 and SR = 1.13
#
# Iteration: 116
# Expected returns of 28.876 with risk of 21.127 and SR = 1.13
#
# Iteration: 117
# Expected returns of 28.874 with risk of 21.127 and SR = 1.13
#
# Iteration: 118
# Expected returns of 28.874 with risk of 21.127 and SR = 1.13
#
# Iteration: 119
# Expected returns of 28.874 with risk of 21.127 and SR = 1.13
#
# Iteration: 120
# Expected returns of 28.873 with risk of 21.127 and SR = 1.13
#
# Iteration: 121
# Expected returns of 28.836 with risk of 21.094 and SR = 1.13
#
# Iteration: 122
# Expected returns of 28.84 with risk of 21.098 and SR = 1.13
#
# Iteration: 123
# Expected returns of 28.842 with risk of 21.1 and SR = 1.13
#
# Iteration: 124
# Expected returns of 28.85 with risk of 21.106 and SR = 1.13
#
# Iteration: 125
# Expected returns of 28.86 with risk of 21.114 and SR = 1.13
#
# Iteration: 126
# Expected returns of 28.86 with risk of 21.114 and SR = 1.13
#
# Iteration: 127
# Expected returns of 28.851 with risk of 21.107 and SR = 1.13
#
# Iteration: 128
# Expected returns of 28.857 with risk of 21.111 and SR = 1.13
#
# Iteration: 129
# Expected returns of 28.848 with risk of 21.102 and SR = 1.13
#
# Iteration: 130
# Expected returns of 28.85 with risk of 21.104 and SR = 1.13
#
# Iteration: 131
# Expected returns of 28.838 with risk of 21.092 and SR = 1.13
#
# Iteration: 132
# Expected returns of 28.846 with risk of 21.1 and SR = 1.13
#
# Iteration: 133
# Expected returns of 28.831 with risk of 21.088 and SR = 1.13
#
# Iteration: 134
# Expected returns of 28.854 with risk of 21.106 and SR = 1.13
#
# Iteration: 135
# Expected returns of 28.853 with risk of 21.105 and SR = 1.13
#
# Iteration: 136
# Expected returns of 28.841 with risk of 21.095 and SR = 1.13
#
# Iteration: 137
# Expected returns of 28.82 with risk of 21.075 and SR = 1.13
#
# Iteration: 138
# Expected returns of 28.829 with risk of 21.083 and SR = 1.13
#
# Iteration: 139
# Expected returns of 28.832 with risk of 21.086 and SR = 1.13
#
# Iteration: 140
# Expected returns of 28.833 with risk of 21.088 and SR = 1.13
#
# Iteration: 141
# Expected returns of 28.833 with risk of 21.088 and SR = 1.13
#
# Iteration: 142
# Expected returns of 28.846 with risk of 21.097 and SR = 1.13
#
# Iteration: 143
# Expected returns of 28.834 with risk of 21.088 and SR = 1.13
#
# Iteration: 144
# Expected returns of 28.846 with risk of 21.094 and SR = 1.13
#
# Iteration: 145
# Expected returns of 28.844 with risk of 21.093 and SR = 1.13
#
# Iteration: 146
# Expected returns of 28.823 with risk of 21.074 and SR = 1.13
#
# Iteration: 147
# Expected returns of 28.827 with risk of 21.078 and SR = 1.13
#
# Iteration: 148
# Expected returns of 28.829 with risk of 21.08 and SR = 1.13
#
# Iteration: 149
# Expected returns of 28.829 with risk of 21.08 and SR = 1.13
#
# Iteration: 150
# Expected returns of 28.827 with risk of 21.077 and SR = 1.13
#
# Iteration: 151
# Expected returns of 28.828 with risk of 21.078 and SR = 1.13
#
# Iteration: 152
# Expected returns of 28.829 with risk of 21.08 and SR = 1.13
#
# Iteration: 153
# Expected returns of 28.83 with risk of 21.08 and SR = 1.13
#
# Iteration: 154
# Expected returns of 28.83 with risk of 21.081 and SR = 1.13
#
# Iteration: 155
# Expected returns of 28.834 with risk of 21.084 and SR = 1.13
#
# Iteration: 156
# Expected returns of 28.81 with risk of 21.065 and SR = 1.13
#
# Iteration: 157
# Expected returns of 28.835 with risk of 21.082 and SR = 1.131
#
# Iteration: 158
# Expected returns of 28.833 with risk of 21.082 and SR = 1.13
#
# Iteration: 159
# Expected returns of 28.819 with risk of 21.071 and SR = 1.13
#
# Iteration: 160
# Expected returns of 28.82 with risk of 21.072 and SR = 1.13
#
# Iteration: 161
# Expected returns of 28.804 with risk of 21.059 and SR = 1.13
#
# Iteration: 162
# Expected returns of 28.806 with risk of 21.06 and SR = 1.13
#
# Iteration: 163
# Expected returns of 28.823 with risk of 21.074 and SR = 1.13
#
# Iteration: 164
# Expected returns of 28.814 with risk of 21.066 and SR = 1.13
#
# Iteration: 165
# Expected returns of 28.837 with risk of 21.084 and SR = 1.131
#
# Iteration: 166
# Expected returns of 28.836 with risk of 21.084 and SR = 1.131
#
# Iteration: 167
# Expected returns of 28.823 with risk of 21.072 and SR = 1.131
#
# Iteration: 168
# Expected returns of 28.823 with risk of 21.072 and SR = 1.131
#
# Iteration: 169
# Expected returns of 28.805 with risk of 21.057 and SR = 1.131
#
# Iteration: 170
# Expected returns of 28.817 with risk of 21.067 and SR = 1.131
#
# Iteration: 171
# Expected returns of 28.809 with risk of 21.06 and SR = 1.131
#
# Iteration: 172
# Expected returns of 28.816 with risk of 21.066 and SR = 1.131
#
# Iteration: 173
# Expected returns of 28.816 with risk of 21.066 and SR = 1.131
#
# Iteration: 174
# Expected returns of 28.816 with risk of 21.066 and SR = 1.131
#
# Iteration: 175
# Expected returns of 28.834 with risk of 21.08 and SR = 1.131
#
# Iteration: 176
# Expected returns of 28.836 with risk of 21.081 and SR = 1.131
#
# Iteration: 177
# Expected returns of 28.835 with risk of 21.081 and SR = 1.131
#
# Iteration: 178
# Expected returns of 28.834 with risk of 21.081 and SR = 1.131
#
# Iteration: 179
# Expected returns of 28.833 with risk of 21.08 and SR = 1.131
#
# Iteration: 180
# Expected returns of 28.829 with risk of 21.076 and SR = 1.131
#
# Iteration: 181
# Expected returns of 28.829 with risk of 21.076 and SR = 1.131
#
# Iteration: 182
# Expected returns of 28.829 with risk of 21.076 and SR = 1.131
#
# Iteration: 183
# Expected returns of 28.829 with risk of 21.076 and SR = 1.131
#
# Iteration: 184
# Expected returns of 28.827 with risk of 21.074 and SR = 1.131
#
# Iteration: 185
# Expected returns of 28.833 with risk of 21.078 and SR = 1.131
#
# Iteration: 186
# Expected returns of 28.832 with risk of 21.077 and SR = 1.131
#
# Iteration: 187
# Expected returns of 28.827 with risk of 21.073 and SR = 1.131
#
# Iteration: 188
# Expected returns of 28.82 with risk of 21.068 and SR = 1.131
#
# Iteration: 189
# Expected returns of 28.83 with risk of 21.077 and SR = 1.131
#
# Iteration: 190
# Expected returns of 28.83 with risk of 21.077 and SR = 1.131
#
# Iteration: 191
# Expected returns of 28.83 with risk of 21.077 and SR = 1.131
#
# Iteration: 192
# Expected returns of 28.83 with risk of 21.077 and SR = 1.131
#
# Iteration: 193
# Expected returns of 28.828 with risk of 21.074 and SR = 1.131
#
# Iteration: 194
# Expected returns of 28.827 with risk of 21.073 and SR = 1.131
#
# Iteration: 195
# Expected returns of 28.828 with risk of 21.074 and SR = 1.131
#
# Iteration: 196
# Expected returns of 28.829 with risk of 21.075 and SR = 1.131
#
# Iteration: 197
# Expected returns of 28.83 with risk of 21.075 and SR = 1.131
#
# Iteration: 198
# Expected returns of 28.832 with risk of 21.077 and SR = 1.131
#
# Iteration: 199
# Expected returns of 28.832 with risk of 21.077 and SR = 1.131
#
# Iteration: 200
# Expected returns of 28.831 with risk of 21.076 and SR = 1.131
#
# Iteration: 201
# Expected returns of 28.833 with risk of 21.078 and SR = 1.131
#
# Iteration: 202
# Expected returns of 28.827 with risk of 21.072 and SR = 1.131
#
# Iteration: 203
# Expected returns of 28.828 with risk of 21.074 and SR = 1.131
#
# Iteration: 204
# Expected returns of 28.828 with risk of 21.074 and SR = 1.131
#
# Iteration: 205
# Expected returns of 28.809 with risk of 21.059 and SR = 1.131
#
# Iteration: 206
# Expected returns of 28.818 with risk of 21.065 and SR = 1.131
#
# Iteration: 207
# Expected returns of 28.819 with risk of 21.066 and SR = 1.131
#
# Iteration: 208
# Expected returns of 28.819 with risk of 21.066 and SR = 1.131
#
# Iteration: 209
# Expected returns of 28.816 with risk of 21.064 and SR = 1.131
#
# Iteration: 210
# Expected returns of 28.816 with risk of 21.064 and SR = 1.131
#
# Iteration: 211
# Expected returns of 28.809 with risk of 21.058 and SR = 1.131
#
# Iteration: 212
# Expected returns of 28.81 with risk of 21.059 and SR = 1.131
#
# Iteration: 213
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
# Iteration: 214
# Expected returns of 28.811 with risk of 21.059 and SR = 1.131
#
# Iteration: 215
# Expected returns of 28.821 with risk of 21.067 and SR = 1.131
#
# Iteration: 216
# Expected returns of 28.802 with risk of 21.052 and SR = 1.131
#
# Iteration: 217
# Expected returns of 28.815 with risk of 21.063 and SR = 1.131
#
# Iteration: 218
# Expected returns of 28.815 with risk of 21.062 and SR = 1.131
#
# Iteration: 219
# Expected returns of 28.816 with risk of 21.064 and SR = 1.131
#
# Iteration: 220
# Expected returns of 28.816 with risk of 21.063 and SR = 1.131
#
# Iteration: 221
# Expected returns of 28.813 with risk of 21.06 and SR = 1.131
#
# Iteration: 222
# Expected returns of 28.813 with risk of 21.061 and SR = 1.131
#
# Iteration: 223
# Expected returns of 28.815 with risk of 21.062 and SR = 1.131
#
# Iteration: 224
# Expected returns of 28.815 with risk of 21.062 and SR = 1.131
#
# Iteration: 225
# Expected returns of 28.814 with risk of 21.061 and SR = 1.131
#
# Iteration: 226
# Expected returns of 28.814 with risk of 21.062 and SR = 1.131
#
# Iteration: 227
# Expected returns of 28.815 with risk of 21.062 and SR = 1.131
#
# Iteration: 228
# Expected returns of 28.814 with risk of 21.062 and SR = 1.131
#
# Iteration: 229
# Expected returns of 28.814 with risk of 21.061 and SR = 1.131
#
# Iteration: 230
# Expected returns of 28.814 with risk of 21.061 and SR = 1.131
#
# Iteration: 231
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 232
# Expected returns of 28.811 with risk of 21.059 and SR = 1.131
#
# Iteration: 233
# Expected returns of 28.807 with risk of 21.056 and SR = 1.131
#
# Iteration: 234
# Expected returns of 28.808 with risk of 21.056 and SR = 1.131
#
# Iteration: 235
# Expected returns of 28.808 with risk of 21.057 and SR = 1.131
#
# Iteration: 236
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 237
# Expected returns of 28.812 with risk of 21.06 and SR = 1.131
#
# Iteration: 238
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 239
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 240
# Expected returns of 28.811 with risk of 21.059 and SR = 1.131
#
# Iteration: 241
# Expected returns of 28.809 with risk of 21.058 and SR = 1.131
#
# Iteration: 242
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 243
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 244
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 245
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 246
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 247
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 248
# Expected returns of 28.811 with risk of 21.058 and SR = 1.131
#
# Iteration: 249
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 250
# Expected returns of 28.811 with risk of 21.058 and SR = 1.131
#
# Iteration: 251
# Expected returns of 28.811 with risk of 21.058 and SR = 1.131
#
# Iteration: 252
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 253
# Expected returns of 28.812 with risk of 21.059 and SR = 1.131
#
# Iteration: 254
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 255
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 256
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 257
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 258
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 259
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 260
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 261
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 262
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 263
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 264
# Expected returns of 28.81 with risk of 21.057 and SR = 1.131
#
# Iteration: 265
# Expected returns of 28.81 with risk of 21.057 and SR = 1.131
#
# Iteration: 266
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 267
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 268
# Expected returns of 28.81 with risk of 21.058 and SR = 1.131
#
# Iteration: 269
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 270
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 271
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 272
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 273
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 274
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 275
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 276
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 277
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 278
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 279
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 280
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 281
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 282
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 283
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 284
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 285
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 286
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 287
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 288
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 289
# Expected returns of 28.808 with risk of 21.056 and SR = 1.131
#
# Iteration: 290
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 291
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 292
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 293
# Expected returns of 28.809 with risk of 21.057 and SR = 1.131
#
# Iteration: 294
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 295
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 296
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 297
# Expected returns of 28.809 with risk of 21.056 and SR = 1.131
#
# Iteration: 298
# Expected returns of 28.81 with risk of 21.057 and SR = 1.131
#
# Iteration: 299
# Expected returns of 28.81 with risk of 21.057 and SR = 1.131
#
# Iteration: 300
# Expected returns of 28.81 with risk of 21.057 and SR = 1.131
#
#
#
# =====================================================
# Portfolio of stocks after all the iterations:
#
# APOLLO HOSPITALS ENTERPRISE LTD. : 0.03906233633637163
# ASIAN PAINTS LTD. : 0.034235999508876465
# BAJAJ FINANCE LTD. : 0.03095199160007503
# BHARAT PETROLEUM CORPN. LTD. : 0.014672226539036376
# BHARTI AIRTEL LTD. : 0.019179483563385197
# BRITANNIA INDUSTRIES LTD. : 0.007687647203863237
# CIPLA LTD. : 0.027405660032464658
# COAL INDIA LTD. : 0.004951578091013417
# DIVI'S LABORATORIES LTD. : 0.03912425906623551
# DR. REDDY'S LABORATORIES LTD. : 0.03637718043043329
# EICHER MOTORS LTD. : 0.0014266177922042079
# GRASIM INDUSTRIES LTD. : 0.016476379844257004
# ADANI PORTS & SPECIAL ECONOMIC ZONE LTD. : 0.027378363262748156
# H C L TECHNOLOGIES LTD. : 0.018070838729407613
# H D F C BANK LTD. : 0.009638036018540849
# H D F C LIFE INSURANCE CO. LTD. : 0.019523131228774956
# HERO MOTOCORP LTD. : 0.011618257396497692
# HINDALCO INDUSTRIES LTD. : 0.01676644910464476
# HINDUSTAN UNILEVER LTD. : 0.020106006632995402
# HOUSING DEVELOPMENT FINANCE CORPN. LTD. : 0.014640055763418857
# I C I C I BANK LTD. : 0.027401931658480684
# I T C LTD. : 0.011633973912824785
# INDUSIND BANK LTD. : 0.004832238772269586
# INFOSYS LTD. : 0.019861484094402918
# J S W STEEL LTD. : 0.02379034076770257
# KOTAK MAHINDRA BANK LTD. : 0.014817645472470579
# ULTRATECH CEMENT LTD. : 0.019838985605466364
# LARSEN & TOUBRO LTD. : 0.014044582191528321
# MAHINDRA & MAHINDRA LTD. : 0.008643310521723466
# TECH MAHINDRA LTD. : 0.024619102326520214
# MARUTI SUZUKI INDIA LTD. : 0.007948938576203757
# N T P C LTD. : 0.009268509946695662
# NESTLE INDIA LTD. : 0.028289327983774416
# OIL & NATURAL GAS CORPN. LTD. : 0.007706652483532653
# TATA CONSULTANCY SERVICES LTD. : 0.028123483429675505
# POWER GRID CORPN. OF INDIA LTD. : 0.01915615729897998
# RELIANCE INDUSTRIES LTD. : 0.029256585351230255
# S B I LIFE INSURANCE CO. LTD. : 0.01980557549917918
# U P L LTD. : 0.018055787504149635
# SHREE CEMENT LTD. : 0.0199603128809079
# STATE BANK OF INDIA : 0.019165222628530543
# SUN PHARMACEUTICAL INDS. LTD. : 0.016729194899712103
# TATA MOTORS LTD. : 0.01403623564149438
# TATA STEEL LTD. : 0.0273748930088855
# TATA CONSUMER PRODUCTS LTD. : 0.03637442493262505
# TITAN COMPANY LTD. : 0.02755067351927199
# AXIS BANK LTD. : 0.014754010674306975
# WIPRO LTD. : 0.03395485621377235
# BAJAJ AUTO LTD. : 0.0198460053428037
# BAJAJ FINSERV LTD. : 0.023867058715634548
#
# Expected returns of 28.81 with risk of 21.057 and Sharpe Ratio of 1.131
# Wall time: 15h 43min 22s

# %%
pd.DataFrame(plotData).to_csv('C2Results.csv')
