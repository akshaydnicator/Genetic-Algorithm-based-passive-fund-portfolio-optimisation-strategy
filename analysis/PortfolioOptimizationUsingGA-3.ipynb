# %%
# %%time
# Import libraries and load monthly stock price data

import numpy as np
import pandas as pd
import math
rf= 0.000195179701757642


##Mean portfolio return = Mean Return * Fractions of Total Capital (Chromosome). 
# Risk-free rate = 0.05 (assumption) 
# Standard deviation of portfolio return = (chromosome * Standard deviation)**2 + Covariance * Respective weights in chromosome.
def mean_portfolio_return(child):
    return np.sum(np.multiply(child,mean_hist_return))
def var_portfolio_return(child):
    part_1 = np.sum(np.multiply(child,sd_hist_return)**2)
    temp_lst=[]
    for i in range(50):
        for j in range(50):
            temp=cov_hist_return.iloc[i][j] * child[i] * child[j]
            temp_lst.append(temp)
    part_2=np.sum(temp_lst)
    return part_1+part_2

# Chromosome: Set of genes i.e. fractions of total capital assigned to each asset
def chromosome(n):
    ''' Generates set of random numbers whose sum is equal to 1
        Input: Number of stocks.
        Output: Array of random numbers'''
    ch = np.random.rand(n)
    return ch/sum(ch)

## Fitness function : The Sharpe ratio, S = (µ − r)/σ
## Maximize return, minimize risk
def fitness_fuction(child):
    ''' This will return the Sharpe ratio for a particular portfolio.
        Input: A child/chromosome (1D Array)
        Output: Sharpe Ratio value (Scalar)'''
    return (mean_portfolio_return(child)-rf)/np.sqrt(var_portfolio_return(child))

def Select_elite_population(population, frac=0.3):
    ''' Select elite population from the total population based on fitness function values.
        Input: Population and fraction of population to be considered as elite.
        Output: Elite population.'''
    population = sorted(population,key = lambda x: fitness_fuction(x),reverse=True)
    percentage_elite_idx = int(np.floor(len(population)* frac))
    return population[:percentage_elite_idx]

def mutation(parent):
    ''' Randomy choosen elements of a chromosome are swapped
        Input: Parent
        Output: Offspring (1D Array)'''
    child=parent.copy()
    n=np.random.choice(range(50),2)
    while (n[0]==n[1]):
        n=np.random.choice(range(50),2)
    child[n[0]],child[n[1]]=child[n[1]],child[n[0]]
    return child

def Heuristic_crossover(parent1,parent2):
    ''' The oﬀsprings are created according to the equation:
            Off_spring A = Best Parent  + β ∗ ( Best Parent − Worst Parent)
            Off_spring B = Worst Parent - β ∗ ( Best Parent − Worst Parent)
                Where β is a random number between 0 and 1.
        Input: 2 Parents
        Output: 2 Children (1d Array)'''
    ff1=fitness_fuction(parent1)
    ff2=fitness_fuction(parent2)
    diff=parent1 - parent2
    beta=np.random.rand()
    if ff1>ff2:
        child1=parent1 + beta * diff
        child2=parent2 - beta * diff
    else:
        child2=parent1 + beta * diff
        child1=parent2 - beta * diff
    return child1,child2

def Arithmetic_crossover(parent1,parent2):
    ''' The oﬀsprings are created according to the equation:
            Off spring A = α ∗ Parent1 + (1 −α) ∗ Parent2
            Off spring B = (1 −α) ∗ Parent1 + α ∗ Parent2
            
                Where α is a random number between 0 and 1.
        Input: 2 Parents
        Output: 2 Children (1d Array)'''
    alpha = np.random.rand()
    child1 = alpha * parent1 + (1-alpha) * parent2
    child2 = (1-alpha) * parent1 + alpha * parent2
    return child1,child2

def next_generation(pop_size,elite,crossover=Arithmetic_crossover):
    ''' Generates new population from elite population with mutation probability as 0.4 and crossover as 0.6. 
        Over the final stages, mutation probability is decreased to 0.1.
        Input: Population Size and elite population.
        Output: Next generation population (2D Array).'''
    new_population=[]
    elite_range=range(len(elite))
    #print(elite_range)
    while len(new_population) < pop_size:
        if len(new_population) > 2*pop_size/3: # In the final stages mutation frequency is decreased.
            mutate_or_crossover = np.random.choice([0, 1], p=[0.6, 0.4])
        else:
            mutate_or_crossover = np.random.choice([0, 1], p=[0.4, 0.6])
        #print(mutate_or_crossover)
        if mutate_or_crossover:
            indx=np.random.choice(elite_range)
            new_population.append(mutation(elite[indx]))
            #print('Mutation!')
        else:
            p1_idx,p2_idx=np.random.choice(elite_range,2)
            c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            chk=0
            for gene in range(50):
                if c1[gene]<0:
                    chk+=1
                else:
                    chk+=0
            if chk>0:
                p1_idx,p2_idx=np.random.choice(elite_range,2)
                c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            
            new_population.extend([c1,c2])
            #print('Crossover!')    
    return new_population


hist_stock_returns = pd.read_csv('Nifty50returnsJan2019-Dec2021.csv')
hist_stock_returns['date'] = pd.to_datetime(hist_stock_returns['date'], format='%d-%m-%Y')
hist_stock_returns.set_index('date',inplace=True)

mean_hist_return=hist_stock_returns.mean()
#print(mean_hist_return)
sd_hist_return=hist_stock_returns.std()
#print(sd_hist_return)
cov_hist_return=hist_stock_returns.cov()
#print(cov_hist_return)
for i in range(50):
    cov_hist_return.iloc[i][i]=0
#print(cov_hist_return)

    
## Determine the Optimum portfolio using Arithmetic Crossover  

n=50 # Number of stocks = 6
pop_size=250 # initial population = 100

# Initial population
population = np.array([chromosome(n) for _ in range(pop_size)])

# Get initial elite population
elite = Select_elite_population(population)

iteration=0 
Expected_returns=10
Expected_risk=15

plotData = {
    "expReturns": [],
    "expRisk": [],
    "SharpeRatio": [] 
}

while (Expected_returns < 30 or Expected_risk > 10) and iteration <= 300:
        
    population = next_generation(250,elite)
    elite = Select_elite_population(population)
    
    Expected_returns=(((1+mean_portfolio_return(elite[0]))**250)-1)*100
    Expected_risk=math.sqrt(var_portfolio_return(elite[0]))*math.sqrt(250)*100
    SR = (Expected_returns-5)/Expected_risk
    
    print('Iteration:',iteration)    
    print('Expected returns of {} with risk of {} and SR = {}\n'.format(round(Expected_returns,ndigits=3),round(Expected_risk,ndigits=3),round(SR,ndigits=3)))
    plotData['expReturns'].extend([Expected_returns])
    plotData['expRisk'].extend([Expected_risk])
    plotData['SharpeRatio'].extend([SR])
    
    iteration+=1

print('\n\n=====================================================\nPortfolio of stocks after all the iterations:\n')
[print(hist_stock_returns.columns[i],':',elite[0][i]) for i in list(range(50))]

print('\nExpected returns of {} with risk of {} and Sharpe Ratio of {}\n'.format(round(Expected_returns,ndigits=3),round(Expected_risk,ndigits=3),round(SR,ndigits=3)))

companies = []
wts = []
for i in list(range(50)):
    companies = companies + [hist_stock_returns.columns[i]]
    wts = wts + [elite[0][i]]

wtDf = pd.DataFrame(columns=['Company','Weight'])
wtDf.Company = companies
wtDf.Weight = wts
wtDf.to_csv('OptimizedWeightsJan2022-Jun2022.csv',index=False)
# Out:
# Iteration: 0
# Expected returns of 30.309 with risk of 21.26 and SR = 1.19
#
# Iteration: 1
# Expected returns of 30.175 with risk of 21.259 and SR = 1.184
#
# Iteration: 2
# Expected returns of 29.847 with risk of 21.225 and SR = 1.171
#
# Iteration: 3
# Expected returns of 29.704 with risk of 21.205 and SR = 1.165
#
# Iteration: 4
# Expected returns of 29.627 with risk of 20.962 and SR = 1.175
#
# Iteration: 5
# Expected returns of 30.456 with risk of 21.267 and SR = 1.197
#
# Iteration: 6
# Expected returns of 30.447 with risk of 21.215 and SR = 1.199
#
# Iteration: 7
# Expected returns of 30.431 with risk of 21.213 and SR = 1.199
#
# Iteration: 8
# Expected returns of 30.384 with risk of 21.196 and SR = 1.198
#
# Iteration: 9
# Expected returns of 30.402 with risk of 21.19 and SR = 1.199
#
# Iteration: 10
# Expected returns of 30.033 with risk of 20.806 and SR = 1.203
#
# Iteration: 11
# Expected returns of 30.374 with risk of 20.983 and SR = 1.209
#
# Iteration: 12
# Expected returns of 30.351 with risk of 20.992 and SR = 1.208
#
# Iteration: 13
# Expected returns of 30.624 with risk of 21.13 and SR = 1.213
#
# Iteration: 14
# Expected returns of 30.739 with risk of 20.914 and SR = 1.231
#
# Iteration: 15
# Expected returns of 30.82 with risk of 20.943 and SR = 1.233
#
# Iteration: 16
# Expected returns of 30.801 with risk of 20.951 and SR = 1.231
#
# Iteration: 17
# Expected returns of 30.712 with risk of 20.893 and SR = 1.231
#
# Iteration: 18
# Expected returns of 30.71 with risk of 20.892 and SR = 1.231
#
# Iteration: 19
# Expected returns of 30.88 with risk of 20.966 and SR = 1.234
#
# Iteration: 20
# Expected returns of 31.072 with risk of 20.93 and SR = 1.246
#
# Iteration: 21
# Expected returns of 31.178 with risk of 20.929 and SR = 1.251
#
# Iteration: 22
# Expected returns of 31.149 with risk of 20.932 and SR = 1.249
#
# Iteration: 23
# Expected returns of 31.234 with risk of 20.987 and SR = 1.25
#
# Iteration: 24
# Expected returns of 31.146 with risk of 20.859 and SR = 1.253
#
# Iteration: 25
# Expected returns of 31.148 with risk of 20.871 and SR = 1.253
#
# Iteration: 26
# Expected returns of 31.306 with risk of 20.901 and SR = 1.259
#
# Iteration: 27
# Expected returns of 31.269 with risk of 20.89 and SR = 1.257
#
# Iteration: 28
# Expected returns of 31.266 with risk of 20.887 and SR = 1.258
#
# Iteration: 29
# Expected returns of 31.329 with risk of 20.935 and SR = 1.258
#
# Iteration: 30
# Expected returns of 31.232 with risk of 20.789 and SR = 1.262
#
# Iteration: 31
# Expected returns of 31.226 with risk of 20.805 and SR = 1.261
#
# Iteration: 32
# Expected returns of 31.378 with risk of 20.88 and SR = 1.263
#
# Iteration: 33
# Expected returns of 31.331 with risk of 20.868 and SR = 1.262
#
# Iteration: 34
# Expected returns of 31.306 with risk of 20.782 and SR = 1.266
#
# Iteration: 35
# Expected returns of 31.325 with risk of 20.777 and SR = 1.267
#
# Iteration: 36
# Expected returns of 31.634 with risk of 20.996 and SR = 1.269
#
# Iteration: 37
# Expected returns of 31.628 with risk of 20.992 and SR = 1.268
#
# Iteration: 38
# Expected returns of 31.328 with risk of 20.785 and SR = 1.267
#
# Iteration: 39
# Expected returns of 31.366 with risk of 20.794 and SR = 1.268
#
# Iteration: 40
# Expected returns of 31.363 with risk of 20.791 and SR = 1.268
#
# Iteration: 41
# Expected returns of 31.365 with risk of 20.794 and SR = 1.268
#
# Iteration: 42
# Expected returns of 31.422 with risk of 20.809 and SR = 1.27
#
# Iteration: 43
# Expected returns of 31.398 with risk of 20.792 and SR = 1.27
#
# Iteration: 44
# Expected returns of 31.399 with risk of 20.793 and SR = 1.27
#
# Iteration: 45
# Expected returns of 31.411 with risk of 20.794 and SR = 1.27
#
# Iteration: 46
# Expected returns of 31.413 with risk of 20.798 and SR = 1.27
#
# Iteration: 47
# Expected returns of 31.362 with risk of 20.76 and SR = 1.27
#
# Iteration: 48
# Expected returns of 31.365 with risk of 20.764 and SR = 1.27
#
# Iteration: 49
# Expected returns of 31.511 with risk of 20.844 and SR = 1.272
#
# Iteration: 50
# Expected returns of 31.455 with risk of 20.816 and SR = 1.271
#
# Iteration: 51
# Expected returns of 31.449 with risk of 20.792 and SR = 1.272
#
# Iteration: 52
# Expected returns of 31.452 with risk of 20.802 and SR = 1.272
#
# Iteration: 53
# Expected returns of 31.47 with risk of 20.796 and SR = 1.273
#
# Iteration: 54
# Expected returns of 31.49 with risk of 20.802 and SR = 1.273
#
# Iteration: 55
# Expected returns of 31.48 with risk of 20.803 and SR = 1.273
#
# Iteration: 56
# Expected returns of 31.434 with risk of 20.771 and SR = 1.273
#
# Iteration: 57
# Expected returns of 31.471 with risk of 20.798 and SR = 1.273
#
# Iteration: 58
# Expected returns of 31.47 with risk of 20.797 and SR = 1.273
#
# Iteration: 59
# Expected returns of 31.499 with risk of 20.799 and SR = 1.274
#
# Iteration: 60
# Expected returns of 31.499 with risk of 20.799 and SR = 1.274
#
# Iteration: 61
# Expected returns of 31.503 with risk of 20.799 and SR = 1.274
#
# Iteration: 62
# Expected returns of 31.501 with risk of 20.799 and SR = 1.274
#
# Iteration: 63
# Expected returns of 31.498 with risk of 20.799 and SR = 1.274
#
# Iteration: 64
# Expected returns of 31.494 with risk of 20.797 and SR = 1.274
#
# Iteration: 65
# Expected returns of 31.55 with risk of 20.832 and SR = 1.274
#
# Iteration: 66
# Expected returns of 31.483 with risk of 20.779 and SR = 1.275
#
# Iteration: 67
# Expected returns of 31.515 with risk of 20.805 and SR = 1.274
#
# Iteration: 68
# Expected returns of 31.491 with risk of 20.786 and SR = 1.274
#
# Iteration: 69
# Expected returns of 31.514 with risk of 20.805 and SR = 1.274
#
# Iteration: 70
# Expected returns of 31.514 with risk of 20.805 and SR = 1.274
#
# Iteration: 71
# Expected returns of 31.52 with risk of 20.802 and SR = 1.275
#
# Iteration: 72
# Expected returns of 31.52 with risk of 20.802 and SR = 1.275
#
# Iteration: 73
# Expected returns of 31.52 with risk of 20.802 and SR = 1.275
#
# Iteration: 74
# Expected returns of 31.518 with risk of 20.802 and SR = 1.275
#
# Iteration: 75
# Expected returns of 31.509 with risk of 20.796 and SR = 1.275
#
# Iteration: 76
# Expected returns of 31.509 with risk of 20.796 and SR = 1.275
#
# Iteration: 77
# Expected returns of 31.534 with risk of 20.806 and SR = 1.275
#
# Iteration: 78
# Expected returns of 31.526 with risk of 20.803 and SR = 1.275
#
# Iteration: 79
# Expected returns of 31.52 with risk of 20.798 and SR = 1.275
#
# Iteration: 80
# Expected returns of 31.519 with risk of 20.798 and SR = 1.275
#
# Iteration: 81
# Expected returns of 31.517 with risk of 20.796 and SR = 1.275
#
# Iteration: 82
# Expected returns of 31.509 with risk of 20.787 and SR = 1.275
#
# Iteration: 83
# Expected returns of 31.509 with risk of 20.787 and SR = 1.275
#
# Iteration: 84
# Expected returns of 31.531 with risk of 20.801 and SR = 1.275
#
# Iteration: 85
# Expected returns of 31.528 with risk of 20.796 and SR = 1.276
#
# Iteration: 86
# Expected returns of 31.527 with risk of 20.796 and SR = 1.276
#
# Iteration: 87
# Expected returns of 31.527 with risk of 20.796 and SR = 1.276
#
# Iteration: 88
# Expected returns of 31.527 with risk of 20.796 and SR = 1.276
#
# Iteration: 89
# Expected returns of 31.537 with risk of 20.803 and SR = 1.276
#
# Iteration: 90
# Expected returns of 31.534 with risk of 20.802 and SR = 1.276
#
# Iteration: 91
# Expected returns of 31.532 with risk of 20.8 and SR = 1.276
#
# Iteration: 92
# Expected returns of 31.531 with risk of 20.798 and SR = 1.276
#
# Iteration: 93
# Expected returns of 31.535 with risk of 20.8 and SR = 1.276
#
# Iteration: 94
# Expected returns of 31.534 with risk of 20.8 and SR = 1.276
#
# Iteration: 95
# Expected returns of 31.531 with risk of 20.797 and SR = 1.276
#
# Iteration: 96
# Expected returns of 31.539 with risk of 20.801 and SR = 1.276
#
# Iteration: 97
# Expected returns of 31.508 with risk of 20.779 and SR = 1.276
#
# Iteration: 98
# Expected returns of 31.511 with risk of 20.782 and SR = 1.276
#
# Iteration: 99
# Expected returns of 31.549 with risk of 20.807 and SR = 1.276
#
# Iteration: 100
# Expected returns of 31.547 with risk of 20.806 and SR = 1.276
#
# Iteration: 101
# Expected returns of 31.515 with risk of 20.782 and SR = 1.276
#
# Iteration: 102
# Expected returns of 31.527 with risk of 20.792 and SR = 1.276
#
# Iteration: 103
# Expected returns of 31.523 with risk of 20.786 and SR = 1.276
#
# Iteration: 104
# Expected returns of 31.523 with risk of 20.787 and SR = 1.276
#
# Iteration: 105
# Expected returns of 31.532 with risk of 20.793 and SR = 1.276
#
# Iteration: 106
# Expected returns of 31.529 with risk of 20.792 and SR = 1.276
# Iteration: 107
# Expected returns of 31.477 with risk of 20.754 and SR = 1.276
#
# Iteration: 108
# Expected returns of 31.485 with risk of 20.76 and SR = 1.276
#
# Iteration: 109
# Expected returns of 31.493 with risk of 20.765 and SR = 1.276
#
# Iteration: 110
# Expected returns of 31.532 with risk of 20.793 and SR = 1.276
#
# Iteration: 111
# Expected returns of 31.531 with risk of 20.792 and SR = 1.276
#
# Iteration: 112
# Expected returns of 31.531 with risk of 20.792 and SR = 1.276
#
# Iteration: 113
# Expected returns of 31.533 with risk of 20.793 and SR = 1.276
#
# Iteration: 114
# Expected returns of 31.519 with risk of 20.781 and SR = 1.276
#
# Iteration: 115
# Expected returns of 31.467 with risk of 20.745 and SR = 1.276
#
# Iteration: 116
# Expected returns of 31.468 with risk of 20.745 and SR = 1.276
#
# Iteration: 117
# Expected returns of 31.533 with risk of 20.791 and SR = 1.276
#
# Iteration: 118
# Expected returns of 31.489 with risk of 20.76 and SR = 1.276
#
# Iteration: 119
# Expected returns of 31.489 with risk of 20.76 and SR = 1.276
#
# Iteration: 120
# Expected returns of 31.47 with risk of 20.746 and SR = 1.276
#
# Iteration: 121
# Expected returns of 31.478 with risk of 20.752 and SR = 1.276
#
# Iteration: 122
# Expected returns of 31.481 with risk of 20.753 and SR = 1.276
#
# Iteration: 123
# Expected returns of 31.495 with risk of 20.762 and SR = 1.276
#
# Iteration: 124
# Expected returns of 31.491 with risk of 20.759 and SR = 1.276
#
# Iteration: 125
# Expected returns of 31.491 with risk of 20.759 and SR = 1.276
#
# Iteration: 126
# Expected returns of 31.491 with risk of 20.759 and SR = 1.276
#
# Iteration: 127
# Expected returns of 31.491 with risk of 20.759 and SR = 1.276
#
# Iteration: 128
# Expected returns of 31.491 with risk of 20.76 and SR = 1.276
#
# Iteration: 129
# Expected returns of 31.489 with risk of 20.757 and SR = 1.276
#
# Iteration: 130
# Expected returns of 31.489 with risk of 20.757 and SR = 1.276
#
# Iteration: 131
# Expected returns of 31.499 with risk of 20.763 and SR = 1.276
#
# Iteration: 132
# Expected returns of 31.499 with risk of 20.763 and SR = 1.276
#
# Iteration: 133
# Expected returns of 31.498 with risk of 20.763 and SR = 1.276
#
# Iteration: 134
# Expected returns of 31.512 with risk of 20.772 and SR = 1.276
#
# Iteration: 135
# Expected returns of 31.497 with risk of 20.762 and SR = 1.276
#
# Iteration: 136
# Expected returns of 31.494 with risk of 20.759 and SR = 1.276
#
# Iteration: 137
# Expected returns of 31.492 with risk of 20.757 and SR = 1.276
#
# Iteration: 138
# Expected returns of 31.492 with risk of 20.758 and SR = 1.276
#
# Iteration: 139
# Expected returns of 31.494 with risk of 20.759 and SR = 1.276
#
# Iteration: 140
# Expected returns of 31.502 with risk of 20.764 and SR = 1.276
#
# Iteration: 141
# Expected returns of 31.5 with risk of 20.763 and SR = 1.276
#
# Iteration: 142
# Expected returns of 31.485 with risk of 20.752 and SR = 1.276
#
# Iteration: 143
# Expected returns of 31.485 with risk of 20.753 and SR = 1.276
#
# Iteration: 144
# Expected returns of 31.495 with risk of 20.759 and SR = 1.276
#
# Iteration: 145
# Expected returns of 31.495 with risk of 20.759 and SR = 1.276
#
# Iteration: 146
# Expected returns of 31.501 with risk of 20.763 and SR = 1.276
#
# Iteration: 147
# Expected returns of 31.523 with risk of 20.778 and SR = 1.276
#
# Iteration: 148
# Expected returns of 31.507 with risk of 20.767 and SR = 1.276
#
# Iteration: 149
# Expected returns of 31.505 with risk of 20.766 and SR = 1.276
#
# Iteration: 150
# Expected returns of 31.505 with risk of 20.766 and SR = 1.276
#
# Iteration: 151
# Expected returns of 31.504 with risk of 20.765 and SR = 1.276
#
# Iteration: 152
# Expected returns of 31.508 with risk of 20.767 and SR = 1.276
#
# Iteration: 153
# Expected returns of 31.509 with risk of 20.768 and SR = 1.276
#
# Iteration: 154
# Expected returns of 31.508 with risk of 20.768 and SR = 1.276
#
# Iteration: 155
# Expected returns of 31.499 with risk of 20.761 and SR = 1.276
#
# Iteration: 156
# Expected returns of 31.513 with risk of 20.771 and SR = 1.276
#
# Iteration: 157
# Expected returns of 31.493 with risk of 20.757 and SR = 1.276
#
# Iteration: 158
# Expected returns of 31.501 with risk of 20.762 and SR = 1.276
#
# Iteration: 159
# Expected returns of 31.509 with risk of 20.768 and SR = 1.276
#
# Iteration: 160
# Expected returns of 31.546 with risk of 20.794 and SR = 1.277
#
# Iteration: 161
# Expected returns of 31.531 with risk of 20.784 and SR = 1.277
#
# Iteration: 162
# Expected returns of 31.534 with risk of 20.785 and SR = 1.277
#
# Iteration: 163
# Expected returns of 31.505 with risk of 20.765 and SR = 1.276
#
# Iteration: 164
# Expected returns of 31.496 with risk of 20.759 and SR = 1.276
#
# Iteration: 165
# Expected returns of 31.511 with risk of 20.768 and SR = 1.276
#
# Iteration: 166
# Expected returns of 31.51 with risk of 20.768 and SR = 1.276
#
# Iteration: 167
# Expected returns of 31.511 with risk of 20.768 and SR = 1.277
#
# Iteration: 168
# Expected returns of 31.51 with risk of 20.768 and SR = 1.276
#
# Iteration: 169
# Expected returns of 31.51 with risk of 20.768 and SR = 1.276
#
# Iteration: 170
# Expected returns of 31.509 with risk of 20.767 and SR = 1.276
#
# Iteration: 171
# Expected returns of 31.508 with risk of 20.766 and SR = 1.276
#
# Iteration: 172
# Expected returns of 31.525 with risk of 20.778 and SR = 1.277
#
# Iteration: 173
# Expected returns of 31.506 with risk of 20.765 and SR = 1.276
#
# Iteration: 174
# Expected returns of 31.506 with risk of 20.765 and SR = 1.276
#
# Iteration: 175
# Expected returns of 31.506 with risk of 20.765 and SR = 1.276
#
# Iteration: 176
# Expected returns of 31.507 with risk of 20.766 and SR = 1.276
#
# Iteration: 177
# Expected returns of 31.514 with risk of 20.77 and SR = 1.277
#
# Iteration: 178
# Expected returns of 31.516 with risk of 20.772 and SR = 1.277
#
# Iteration: 179
# Expected returns of 31.516 with risk of 20.772 and SR = 1.277
#
# Iteration: 180
# Expected returns of 31.509 with risk of 20.767 and SR = 1.277
#
# Iteration: 181
# Expected returns of 31.513 with risk of 20.77 and SR = 1.277
#
# Iteration: 182
# Expected returns of 31.512 with risk of 20.769 and SR = 1.277
#
# Iteration: 183
# Expected returns of 31.512 with risk of 20.769 and SR = 1.277
#
# Iteration: 184
# Expected returns of 31.511 with risk of 20.768 and SR = 1.277
#
# Iteration: 185
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 186
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 187
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 188
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 189
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 190
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 191
# Expected returns of 31.511 with risk of 20.768 and SR = 1.277
#
# Iteration: 192
# Expected returns of 31.51 with risk of 20.767 and SR = 1.277
#
# Iteration: 193
# Expected returns of 31.513 with risk of 20.769 and SR = 1.277
#
# Iteration: 194
# Expected returns of 31.51 with risk of 20.767 and SR = 1.277
#
# Iteration: 195
# Expected returns of 31.51 with risk of 20.767 and SR = 1.277
#
# Iteration: 196
# Expected returns of 31.51 with risk of 20.767 and SR = 1.277
#
# Iteration: 197
# Expected returns of 31.508 with risk of 20.765 and SR = 1.277
#
# Iteration: 198
# Expected returns of 31.511 with risk of 20.767 and SR = 1.277
#
# Iteration: 199
# Expected returns of 31.525 with risk of 20.777 and SR = 1.277
#
# Iteration: 200
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 201
# Expected returns of 31.515 with risk of 20.77 and SR = 1.277
#
# Iteration: 202
# Expected returns of 31.515 with risk of 20.77 and SR = 1.277
#
# Iteration: 203
# Expected returns of 31.517 with risk of 20.772 and SR = 1.277
#
# Iteration: 204
# Expected returns of 31.521 with risk of 20.775 and SR = 1.277
#
# Iteration: 205
# Expected returns of 31.521 with risk of 20.775 and SR = 1.277
#
# Iteration: 206
# Expected returns of 31.519 with risk of 20.773 and SR = 1.277
#
# Iteration: 207
# Expected returns of 31.528 with risk of 20.779 and SR = 1.277
#
# Iteration: 208
# Expected returns of 31.527 with risk of 20.779 and SR = 1.277
#
# Iteration: 209
# Expected returns of 31.527 with risk of 20.779 and SR = 1.277
#
# Iteration: 210
# Expected returns of 31.528 with risk of 20.779 and SR = 1.277
#
# Iteration: 211
# Expected returns of 31.525 with risk of 20.777 and SR = 1.277
#
# Iteration: 212
# Expected returns of 31.519 with risk of 20.773 and SR = 1.277
# Iteration: 213
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 214
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 215
# Expected returns of 31.524 with risk of 20.776 and SR = 1.277
#
# Iteration: 216
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 217
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 218
# Expected returns of 31.529 with risk of 20.78 and SR = 1.277
#
# Iteration: 219
# Expected returns of 31.529 with risk of 20.78 and SR = 1.277
#
# Iteration: 220
# Expected returns of 31.522 with risk of 20.775 and SR = 1.277
#
# Iteration: 221
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 222
# Expected returns of 31.522 with risk of 20.775 and SR = 1.277
#
# Iteration: 223
# Expected returns of 31.524 with risk of 20.776 and SR = 1.277
#
# Iteration: 224
# Expected returns of 31.524 with risk of 20.776 and SR = 1.277
#
# Iteration: 225
# Expected returns of 31.525 with risk of 20.777 and SR = 1.277
#
# Iteration: 226
# Expected returns of 31.524 with risk of 20.776 and SR = 1.277
#
# Iteration: 227
# Expected returns of 31.528 with risk of 20.779 and SR = 1.277
#
# Iteration: 228
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 229
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 230
# Expected returns of 31.514 with risk of 20.769 and SR = 1.277
#
# Iteration: 231
# Expected returns of 31.518 with risk of 20.771 and SR = 1.277
#
# Iteration: 232
# Expected returns of 31.518 with risk of 20.771 and SR = 1.277
#
# Iteration: 233
# Expected returns of 31.518 with risk of 20.772 and SR = 1.277
#
# Iteration: 234
# Expected returns of 31.518 with risk of 20.772 and SR = 1.277
#
# Iteration: 235
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 236
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 237
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 238
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 239
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 240
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 241
# Expected returns of 31.517 with risk of 20.771 and SR = 1.277
#
# Iteration: 242
# Expected returns of 31.518 with risk of 20.771 and SR = 1.277
#
# Iteration: 243
# Expected returns of 31.518 with risk of 20.771 and SR = 1.277
#
# Iteration: 244
# Expected returns of 31.517 with risk of 20.771 and SR = 1.277
#
# Iteration: 245
# Expected returns of 31.518 with risk of 20.771 and SR = 1.277
#
# Iteration: 246
# Expected returns of 31.518 with risk of 20.771 and SR = 1.277
#
# Iteration: 247
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 248
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 249
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 250
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 251
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 252
# Expected returns of 31.524 with risk of 20.776 and SR = 1.277
#
# Iteration: 253
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 254
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 255
# Expected returns of 31.516 with risk of 20.77 and SR = 1.277
#
# Iteration: 256
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 257
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 258
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 259
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 260
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 261
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 262
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 263
# Expected returns of 31.523 with risk of 20.775 and SR = 1.277
#
# Iteration: 264
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 265
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 266
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 267
# Expected returns of 31.519 with risk of 20.772 and SR = 1.277
#
# Iteration: 268
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 269
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 270
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 271
# Expected returns of 31.524 with risk of 20.775 and SR = 1.277
#
# Iteration: 272
# Expected returns of 31.523 with risk of 20.775 and SR = 1.277
#
# Iteration: 273
# Expected returns of 31.523 with risk of 20.775 and SR = 1.277
#
# Iteration: 274
# Expected returns of 31.523 with risk of 20.775 and SR = 1.277
#
# Iteration: 275
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 276
# Expected returns of 31.523 with risk of 20.775 and SR = 1.277
#
# Iteration: 277
# Expected returns of 31.523 with risk of 20.775 and SR = 1.277
#
# Iteration: 278
# Expected returns of 31.523 with risk of 20.774 and SR = 1.277
#
# Iteration: 279
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 280
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 281
# Expected returns of 31.523 with risk of 20.774 and SR = 1.277
#
# Iteration: 282
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 283
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 284
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 285
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 286
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 287
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 288
# Expected returns of 31.521 with risk of 20.773 and SR = 1.277
#
# Iteration: 289
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 290
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 291
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 292
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 293
# Expected returns of 31.52 with risk of 20.773 and SR = 1.277
#
# Iteration: 294
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 295
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 296
# Expected returns of 31.521 with risk of 20.774 and SR = 1.277
#
# Iteration: 297
# Expected returns of 31.523 with risk of 20.774 and SR = 1.277
#
# Iteration: 298
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 299
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
# Iteration: 300
# Expected returns of 31.522 with risk of 20.774 and SR = 1.277
#
#
#
# =====================================================
# Portfolio of stocks after all the iterations:
#
# APOLLO HOSPITALS ENTERPRISE LTD. : 0.032734261878664045
# ASIAN PAINTS LTD. : 0.031012638964655347
# BAJAJ FINANCE LTD. : 0.028234239528953528
# BHARAT PETROLEUM CORPN. LTD. : 0.011910176477456399
# BHARTI AIRTEL LTD. : 0.02871850123366846
# BRITANNIA INDUSTRIES LTD. : 0.012296314284955607
# CIPLA LTD. : 0.028349178389095266
# COAL INDIA LTD. : 0.010032350379632779
# DIVI'S LABORATORIES LTD. : 0.032732912236935
# DR. REDDY'S LABORATORIES LTD. : 0.028683989101269354
# EICHER MOTORS LTD. : 0.008233316893951806
# GRASIM INDUSTRIES LTD. : 0.017903017848229792
# ADANI PORTS & SPECIAL ECONOMIC ZONE LTD. : 0.024324346756805795
# H C L TECHNOLOGIES LTD. : 0.02125767591850252
# H D F C BANK LTD. : 0.010252135312720491
# H D F C LIFE INSURANCE CO. LTD. : 0.01779859715227732
# HERO MOTOCORP LTD. : 0.01003181102866978
# HINDALCO INDUSTRIES LTD. : 0.017046949377816013
# HINDUSTAN UNILEVER LTD. : 0.015918692900453855
# HOUSING DEVELOPMENT FINANCE CORPN. LTD. : 0.011916549308880697
# I C I C I BANK LTD. : 0.019589589308883267
# I T C LTD. : 0.010569819726654084
# INDUSIND BANK LTD. : 0.008379691732850594
# INFOSYS LTD. : 0.03225877197859829
# J S W STEEL LTD. : 0.01918715456475363
# KOTAK MAHINDRA BANK LTD. : 0.015343216836346703
# ULTRATECH CEMENT LTD. : 0.019544729078741063
# LARSEN & TOUBRO LTD. : 0.012296577852897072
# MAHINDRA & MAHINDRA LTD. : 0.01087451654193736
# TECH MAHINDRA LTD. : 0.0310093487499919
# MARUTI SUZUKI INDIA LTD. : 0.010471023881350064
# N T P C LTD. : 0.010823458028463255
# NESTLE INDIA LTD. : 0.026725735675041218
# OIL & NATURAL GAS CORPN. LTD. : 0.010585113676295766
# TATA CONSULTANCY SERVICES LTD. : 0.028605397548704052
# POWER GRID CORPN. OF INDIA LTD. : 0.014888885089955724
# RELIANCE INDUSTRIES LTD. : 0.02573210942624249
# S B I LIFE INSURANCE CO. LTD. : 0.02823393334981914
# U P L LTD. : 0.011918723574872205
# SHREE CEMENT LTD. : 0.015714533039909103
# STATE BANK OF INDIA : 0.01487487754889175
# SUN PHARMACEUTICAL INDS. LTD. : 0.028302753541970167
# TATA MOTORS LTD. : 0.02869794410524039
# TATA STEEL LTD. : 0.02420568129965664
# TATA CONSUMER PRODUCTS LTD. : 0.03224751865277565
# TITAN COMPANY LTD. : 0.030980944487573263
# AXIS BANK LTD. : 0.010619189821455533
# WIPRO LTD. : 0.03046397715492173
# BAJAJ AUTO LTD. : 0.01229994830487122
# BAJAJ FINSERV LTD. : 0.02516718044674292
#
# Expected returns of 31.522 with risk of 20.774 and Sharpe Ratio of 1.277
# Wall time: 15h 46min 29s

# %%
pd.DataFrame(plotData).to_csv('C3Results.csv')
