# %%
# %%time
# Import libraries and load monthly stock price data

import numpy as np
import pandas as pd
import math
rf= 0.000195179701757642


##Mean portfolio return = Mean Return * Fractions of Total Capital (Chromosome). 
# Risk-free rate = 0.05 (assumption) 
# Standard deviation of portfolio return = (chromosome * Standard deviation)**2 + Covariance * Respective weights in chromosome.
def mean_portfolio_return(child):
    return np.sum(np.multiply(child,mean_hist_return))
def var_portfolio_return(child):
    part_1 = np.sum(np.multiply(child,sd_hist_return)**2)
    temp_lst=[]
    for i in range(50):
        for j in range(50):
            temp=cov_hist_return.iloc[i][j] * child[i] * child[j]
            temp_lst.append(temp)
    part_2=np.sum(temp_lst)
    return part_1+part_2

# Chromosome: Set of genes i.e. fractions of total capital assigned to each asset
def chromosome(n):
    ''' Generates set of random numbers whose sum is equal to 1
        Input: Number of stocks.
        Output: Array of random numbers'''
    ch = np.random.rand(n)
    return ch/sum(ch)

## Fitness function : The Sharpe ratio, S = (µ − r)/σ
## Maximize return, minimize risk
def fitness_fuction(child):
    ''' This will return the Sharpe ratio for a particular portfolio.
        Input: A child/chromosome (1D Array)
        Output: Sharpe Ratio value (Scalar)'''
    return (mean_portfolio_return(child)-rf)/np.sqrt(var_portfolio_return(child))

def Select_elite_population(population, frac=0.3):
    ''' Select elite population from the total population based on fitness function values.
        Input: Population and fraction of population to be considered as elite.
        Output: Elite population.'''
    population = sorted(population,key = lambda x: fitness_fuction(x),reverse=True)
    percentage_elite_idx = int(np.floor(len(population)* frac))
    return population[:percentage_elite_idx]

def mutation(parent):
    ''' Randomy choosen elements of a chromosome are swapped
        Input: Parent
        Output: Offspring (1D Array)'''
    child=parent.copy()
    n=np.random.choice(range(50),2)
    while (n[0]==n[1]):
        n=np.random.choice(range(50),2)
    child[n[0]],child[n[1]]=child[n[1]],child[n[0]]
    return child

def Heuristic_crossover(parent1,parent2):
    ''' The oﬀsprings are created according to the equation:
            Off_spring A = Best Parent  + β ∗ ( Best Parent − Worst Parent)
            Off_spring B = Worst Parent - β ∗ ( Best Parent − Worst Parent)
                Where β is a random number between 0 and 1.
        Input: 2 Parents
        Output: 2 Children (1d Array)'''
    ff1=fitness_fuction(parent1)
    ff2=fitness_fuction(parent2)
    diff=parent1 - parent2
    beta=np.random.rand()
    if ff1>ff2:
        child1=parent1 + beta * diff
        child2=parent2 - beta * diff
    else:
        child2=parent1 + beta * diff
        child1=parent2 - beta * diff
    return child1,child2

def Arithmetic_crossover(parent1,parent2):
    ''' The oﬀsprings are created according to the equation:
            Off spring A = α ∗ Parent1 + (1 −α) ∗ Parent2
            Off spring B = (1 −α) ∗ Parent1 + α ∗ Parent2
            
                Where α is a random number between 0 and 1.
        Input: 2 Parents
        Output: 2 Children (1d Array)'''
    alpha = np.random.rand()
    child1 = alpha * parent1 + (1-alpha) * parent2
    child2 = (1-alpha) * parent1 + alpha * parent2
    return child1,child2

def next_generation(pop_size,elite,crossover=Arithmetic_crossover):
    ''' Generates new population from elite population with mutation probability as 0.4 and crossover as 0.6. 
        Over the final stages, mutation probability is decreased to 0.1.
        Input: Population Size and elite population.
        Output: Next generation population (2D Array).'''
    new_population=[]
    elite_range=range(len(elite))
    #print(elite_range)
    while len(new_population) < pop_size:
        if len(new_population) > 2*pop_size/3: # In the final stages mutation frequency is decreased.
            mutate_or_crossover = np.random.choice([0, 1], p=[0.6, 0.4])
        else:
            mutate_or_crossover = np.random.choice([0, 1], p=[0.4, 0.6])
        #print(mutate_or_crossover)
        if mutate_or_crossover:
            indx=np.random.choice(elite_range)
            new_population.append(mutation(elite[indx]))
            #print('Mutation!')
        else:
            p1_idx,p2_idx=np.random.choice(elite_range,2)
            c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            chk=0
            for gene in range(50):
                if c1[gene]<0:
                    chk+=1
                else:
                    chk+=0
            if chk>0:
                p1_idx,p2_idx=np.random.choice(elite_range,2)
                c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            
            new_population.extend([c1,c2])
            #print('Crossover!')    
    return new_population


hist_stock_returns = pd.read_csv('Nifty50returnsDec2017-Dec2020.csv')
hist_stock_returns['date'] = pd.to_datetime(hist_stock_returns['date'], format='%d-%m-%Y')
hist_stock_returns.set_index('date',inplace=True)

mean_hist_return=hist_stock_returns.mean()
#print(mean_hist_return)
sd_hist_return=hist_stock_returns.std()
#print(sd_hist_return)
cov_hist_return=hist_stock_returns.cov()
#print(cov_hist_return)
for i in range(50):
    cov_hist_return.iloc[i][i]=0
#print(cov_hist_return)

    
## Determine the Optimum portfolio using Arithmetic Crossover  

n=50 # Number of stocks = 6
pop_size=250 # initial population = 100

# Initial population
population = np.array([chromosome(n) for _ in range(pop_size)])

# Get initial elite population
elite = Select_elite_population(population)

iteration=0 
Expected_returns=10
Expected_risk=15

plotData = {
    "expReturns": [],
    "expRisk": [],
    "SharpeRatio": [] 
}

while (Expected_returns < 30 or Expected_risk > 10) and iteration <= 300:
        
    population = next_generation(250,elite)
    elite = Select_elite_population(population)
    
    Expected_returns=(((1+mean_portfolio_return(elite[0]))**250)-1)*100
    Expected_risk=math.sqrt(var_portfolio_return(elite[0]))*math.sqrt(250)*100
    SR = (Expected_returns-5)/Expected_risk
    
    print('Iteration:',iteration)    
    print('Expected returns of {} with risk of {} and SR = {}\n'.format(round(Expected_returns,ndigits=2),round(Expected_risk,ndigits=2),round(SR,ndigits=2)))
    plotData['expReturns'].extend([Expected_returns])
    plotData['expRisk'].extend([Expected_risk])
    plotData['SharpeRatio'].extend([SR])
    
    iteration+=1

print('\n\n=====================================================\nPortfolio of stocks after all the iterations:\n')
[print(hist_stock_returns.columns[i],':',elite[0][i]) for i in list(range(50))]

print('\nExpected returns of {} with risk of {} and Sharpe Ratio of {}\n'.format(round(Expected_returns,ndigits=2),round(Expected_risk,ndigits=2),round(SR,ndigits=2)))

companies = []
wts = []
for i in list(range(50)):
    companies = companies + [hist_stock_returns.columns[i]]
    wts = wts + [elite[0][i]]

wtDf = pd.DataFrame(columns=['Company','Weight'])
wtDf.Company = companies
wtDf.Weight = wts
wtDf.to_csv('OptimizedWeightsJan2021-Jun2021.csv',index=False)
# Out:
# Iteration: 0
# Expected returns of 16.7 with risk of 20.77 and SR = 0.56
#
# Iteration: 1
# Expected returns of 17.34 with risk of 20.58 and SR = 0.6
#
# Iteration: 2
# Expected returns of 17.25 with risk of 20.48 and SR = 0.6
#
# Iteration: 3
# Expected returns of 17.67 with risk of 20.59 and SR = 0.62
#
# Iteration: 4
# Expected returns of 17.81 with risk of 20.6 and SR = 0.62
#
# Iteration: 5
# Expected returns of 18.44 with risk of 20.48 and SR = 0.66
#
# Iteration: 6
# Expected returns of 18.23 with risk of 20.46 and SR = 0.65
#
# Iteration: 7
# Expected returns of 18.46 with risk of 20.41 and SR = 0.66
#
# Iteration: 8
# Expected returns of 18.37 with risk of 20.41 and SR = 0.66
#
# Iteration: 9
# Expected returns of 18.72 with risk of 20.48 and SR = 0.67
#
# Iteration: 10
# Expected returns of 19.01 with risk of 20.32 and SR = 0.69
#
# Iteration: 11
# Expected returns of 19.31 with risk of 20.5 and SR = 0.7
#
# Iteration: 12
# Expected returns of 19.27 with risk of 20.51 and SR = 0.7
#
# Iteration: 13
# Expected returns of 19.25 with risk of 20.42 and SR = 0.7
#
# Iteration: 14
# Expected returns of 19.21 with risk of 20.34 and SR = 0.7
#
# Iteration: 15
# Expected returns of 19.7 with risk of 20.25 and SR = 0.73
#
# Iteration: 16
# Expected returns of 19.8 with risk of 20.28 and SR = 0.73
#
# Iteration: 17
# Expected returns of 19.84 with risk of 20.3 and SR = 0.73
#
# Iteration: 18
# Expected returns of 19.88 with risk of 20.32 and SR = 0.73
#
# Iteration: 19
# Expected returns of 20.0 with risk of 20.23 and SR = 0.74
#
# Iteration: 20
# Expected returns of 20.12 with risk of 20.26 and SR = 0.75
#
# Iteration: 21
# Expected returns of 20.34 with risk of 20.39 and SR = 0.75
#
# Iteration: 22
# Expected returns of 20.4 with risk of 20.42 and SR = 0.75
#
# Iteration: 23
# Expected returns of 20.24 with risk of 20.23 and SR = 0.75
#
# Iteration: 24
# Expected returns of 20.35 with risk of 20.23 and SR = 0.76
#
# Iteration: 25
# Expected returns of 20.51 with risk of 20.26 and SR = 0.77
#
# Iteration: 26
# Expected returns of 20.57 with risk of 20.21 and SR = 0.77
#
# Iteration: 27
# Expected returns of 20.56 with risk of 20.21 and SR = 0.77
#
# Iteration: 28
# Expected returns of 20.76 with risk of 20.18 and SR = 0.78
#
# Iteration: 29
# Expected returns of 20.86 with risk of 20.16 and SR = 0.79
#
# Iteration: 30
# Expected returns of 20.85 with risk of 20.17 and SR = 0.79
#
# Iteration: 31
# Expected returns of 20.81 with risk of 20.16 and SR = 0.78
#
# Iteration: 32
# Expected returns of 20.76 with risk of 20.16 and SR = 0.78
#
# Iteration: 33
# Expected returns of 20.88 with risk of 20.18 and SR = 0.79
#
# Iteration: 34
# Expected returns of 20.85 with risk of 20.17 and SR = 0.79
#
# Iteration: 35
# Expected returns of 20.85 with risk of 20.17 and SR = 0.79
#
# Iteration: 36
# Expected returns of 20.85 with risk of 20.16 and SR = 0.79
#
# Iteration: 37
# Expected returns of 20.86 with risk of 20.19 and SR = 0.79
#
# Iteration: 38
# Expected returns of 20.88 with risk of 20.07 and SR = 0.79
#
# Iteration: 39
# Expected returns of 20.9 with risk of 20.05 and SR = 0.79
#
# Iteration: 40
# Expected returns of 20.99 with risk of 20.1 and SR = 0.8
#
# Iteration: 41
# Expected returns of 20.98 with risk of 20.12 and SR = 0.79
#
# Iteration: 42
# Expected returns of 20.98 with risk of 20.11 and SR = 0.79
#
# Iteration: 43
# Expected returns of 20.9 with risk of 20.0 and SR = 0.79
#
# Iteration: 44
# Expected returns of 21.01 with risk of 20.08 and SR = 0.8
#
# Iteration: 45
# Expected returns of 21.01 with risk of 20.08 and SR = 0.8
#
# Iteration: 46
# Expected returns of 21.12 with risk of 20.22 and SR = 0.8
#
# Iteration: 47
# Expected returns of 21.1 with risk of 20.11 and SR = 0.8
#
# Iteration: 48
# Expected returns of 21.11 with risk of 20.1 and SR = 0.8
#
# Iteration: 49
# Expected returns of 21.12 with risk of 20.12 and SR = 0.8
#
# Iteration: 50
# Expected returns of 21.12 with risk of 20.12 and SR = 0.8
#
# Iteration: 51
# Expected returns of 21.02 with risk of 20.0 and SR = 0.8
#
# Iteration: 52
# Expected returns of 21.09 with risk of 20.05 and SR = 0.8
#
# Iteration: 53
# Expected returns of 21.11 with risk of 20.07 and SR = 0.8
#
# Iteration: 54
# Expected returns of 21.32 with risk of 20.24 and SR = 0.81
#
# Iteration: 55
# Expected returns of 21.28 with risk of 20.21 and SR = 0.81
#
# Iteration: 56
# Expected returns of 21.27 with risk of 20.21 and SR = 0.81
#
# Iteration: 57
# Expected returns of 21.31 with risk of 20.22 and SR = 0.81
#
# Iteration: 58
# Expected returns of 21.31 with risk of 20.22 and SR = 0.81
#
# Iteration: 59
# Expected returns of 21.2 with risk of 20.07 and SR = 0.81
#
# Iteration: 60
# Expected returns of 21.16 with risk of 20.01 and SR = 0.81
#
# Iteration: 61
# Expected returns of 21.16 with risk of 20.02 and SR = 0.81
#
# Iteration: 62
# Expected returns of 21.26 with risk of 20.13 and SR = 0.81
#
# Iteration: 63
# Expected returns of 21.29 with risk of 20.13 and SR = 0.81
#
# Iteration: 64
# Expected returns of 21.17 with risk of 20.01 and SR = 0.81
#
# Iteration: 65
# Expected returns of 21.22 with risk of 20.06 and SR = 0.81
#
# Iteration: 66
# Expected returns of 21.18 with risk of 19.98 and SR = 0.81
#
# Iteration: 67
# Expected returns of 21.18 with risk of 19.98 and SR = 0.81
#
# Iteration: 68
# Expected returns of 21.23 with risk of 20.05 and SR = 0.81
#
# Iteration: 69
# Expected returns of 21.19 with risk of 19.99 and SR = 0.81
#
# Iteration: 70
# Expected returns of 21.28 with risk of 20.09 and SR = 0.81
#
# Iteration: 71
# Expected returns of 21.27 with risk of 20.08 and SR = 0.81
#
# Iteration: 72
# Expected returns of 21.27 with risk of 20.08 and SR = 0.81
#
# Iteration: 73
# Expected returns of 21.35 with risk of 20.14 and SR = 0.81
#
# Iteration: 74
# Expected returns of 21.34 with risk of 20.13 and SR = 0.81
#
# Iteration: 75
# Expected returns of 21.23 with risk of 20.01 and SR = 0.81
#
# Iteration: 76
# Expected returns of 21.31 with risk of 20.07 and SR = 0.81
#
# Iteration: 77
# Expected returns of 21.3 with risk of 20.07 and SR = 0.81
#
# Iteration: 78
# Expected returns of 21.36 with risk of 20.14 and SR = 0.81
#
# Iteration: 79
# Expected returns of 21.31 with risk of 20.06 and SR = 0.81
#
# Iteration: 80
# Expected returns of 21.31 with risk of 20.06 and SR = 0.81
#
# Iteration: 81
# Expected returns of 21.3 with risk of 20.06 and SR = 0.81
#
# Iteration: 82
# Expected returns of 21.36 with risk of 20.11 and SR = 0.81
#
# Iteration: 83
# Expected returns of 21.31 with risk of 20.06 and SR = 0.81
#
# Iteration: 84
# Expected returns of 21.3 with risk of 20.06 and SR = 0.81
#
# Iteration: 85
# Expected returns of 21.33 with risk of 20.06 and SR = 0.81
#
# Iteration: 86
# Expected returns of 21.33 with risk of 20.06 and SR = 0.81
#
# Iteration: 87
# Expected returns of 21.34 with risk of 20.06 and SR = 0.81
#
# Iteration: 88
# Expected returns of 21.38 with risk of 20.08 and SR = 0.82
#
# Iteration: 89
# Expected returns of 21.36 with risk of 20.08 and SR = 0.81
#
# Iteration: 90
# Expected returns of 21.35 with risk of 20.07 and SR = 0.81
#
# Iteration: 91
# Expected returns of 21.35 with risk of 20.07 and SR = 0.81
#
# Iteration: 92
# Expected returns of 21.37 with risk of 20.08 and SR = 0.81
#
# Iteration: 93
# Expected returns of 21.31 with risk of 20.01 and SR = 0.82
#
# Iteration: 94
# Expected returns of 21.35 with risk of 20.07 and SR = 0.81
#
# Iteration: 95
# Expected returns of 21.39 with risk of 20.1 and SR = 0.82
#
# Iteration: 96
# Expected returns of 21.34 with risk of 20.05 and SR = 0.81
#
# Iteration: 97
# Expected returns of 21.37 with risk of 20.08 and SR = 0.82
#
# Iteration: 98
# Expected returns of 21.38 with risk of 20.08 and SR = 0.82
#
# Iteration: 99
# Expected returns of 21.37 with risk of 20.08 and SR = 0.82
#
# Iteration: 100
# Expected returns of 21.37 with risk of 20.07 and SR = 0.82
#
# Iteration: 101
# Expected returns of 21.36 with risk of 20.07 and SR = 0.82
#
# Iteration: 102
# Expected returns of 21.35 with risk of 20.05 and SR = 0.82
#
# Iteration: 103
# Expected returns of 21.36 with risk of 20.06 and SR = 0.82
#
# Iteration: 104
# Expected returns of 21.35 with risk of 20.05 and SR = 0.82
#
# Iteration: 105
# Expected returns of 21.35 with risk of 20.05 and SR = 0.82
#
# Iteration: 106
# Expected returns of 21.34 with risk of 20.04 and SR = 0.82
#
# Iteration: 107
# Expected returns of 21.35 with risk of 20.02 and SR = 0.82
#
# Iteration: 108
# Expected returns of 21.35 with risk of 20.02 and SR = 0.82
#
# Iteration: 109
# Expected returns of 21.35 with risk of 20.04 and SR = 0.82
#
# Iteration: 110
# Expected returns of 21.35 with risk of 20.04 and SR = 0.82
#
# Iteration: 111
# Expected returns of 21.34 with risk of 20.02 and SR = 0.82
# Iteration: 112
# Expected returns of 21.38 with risk of 20.06 and SR = 0.82
#
# Iteration: 113
# Expected returns of 21.38 with risk of 20.06 and SR = 0.82
#
# Iteration: 114
# Expected returns of 21.37 with risk of 20.06 and SR = 0.82
#
# Iteration: 115
# Expected returns of 21.35 with risk of 20.03 and SR = 0.82
#
# Iteration: 116
# Expected returns of 21.35 with risk of 20.03 and SR = 0.82
#
# Iteration: 117
# Expected returns of 21.4 with risk of 20.08 and SR = 0.82
#
# Iteration: 118
# Expected returns of 21.4 with risk of 20.08 and SR = 0.82
#
# Iteration: 119
# Expected returns of 21.4 with risk of 20.07 and SR = 0.82
#
# Iteration: 120
# Expected returns of 21.35 with risk of 20.02 and SR = 0.82
#
# Iteration: 121
# Expected returns of 21.35 with risk of 20.01 and SR = 0.82
#
# Iteration: 122
# Expected returns of 21.35 with risk of 20.01 and SR = 0.82
#
# Iteration: 123
# Expected returns of 21.36 with risk of 20.03 and SR = 0.82
#
# Iteration: 124
# Expected returns of 21.35 with risk of 20.02 and SR = 0.82
#
# Iteration: 125
# Expected returns of 21.38 with risk of 20.05 and SR = 0.82
#
# Iteration: 126
# Expected returns of 21.36 with risk of 20.02 and SR = 0.82
#
# Iteration: 127
# Expected returns of 21.37 with risk of 20.04 and SR = 0.82
#
# Iteration: 128
# Expected returns of 21.36 with risk of 20.02 and SR = 0.82
#
# Iteration: 129
# Expected returns of 21.36 with risk of 20.03 and SR = 0.82
#
# Iteration: 130
# Expected returns of 21.39 with risk of 20.06 and SR = 0.82
#
# Iteration: 131
# Expected returns of 21.39 with risk of 20.06 and SR = 0.82
#
# Iteration: 132
# Expected returns of 21.35 with risk of 20.02 and SR = 0.82
#
# Iteration: 133
# Expected returns of 21.36 with risk of 20.03 and SR = 0.82
#
# Iteration: 134
# Expected returns of 21.36 with risk of 20.03 and SR = 0.82
#
# Iteration: 135
# Expected returns of 21.39 with risk of 20.06 and SR = 0.82
#
# Iteration: 136
# Expected returns of 21.37 with risk of 20.03 and SR = 0.82
#
# Iteration: 137
# Expected returns of 21.37 with risk of 20.03 and SR = 0.82
#
# Iteration: 138
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 139
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 140
# Expected returns of 21.39 with risk of 20.05 and SR = 0.82
#
# Iteration: 141
# Expected returns of 21.39 with risk of 20.06 and SR = 0.82
#
# Iteration: 142
# Expected returns of 21.39 with risk of 20.06 and SR = 0.82
#
# Iteration: 143
# Expected returns of 21.39 with risk of 20.05 and SR = 0.82
#
# Iteration: 144
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 145
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 146
# Expected returns of 21.39 with risk of 20.05 and SR = 0.82
#
# Iteration: 147
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 148
# Expected returns of 21.39 with risk of 20.05 and SR = 0.82
#
# Iteration: 149
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 150
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 151
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 152
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 153
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 154
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 155
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 156
# Expected returns of 21.36 with risk of 20.02 and SR = 0.82
#
# Iteration: 157
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 158
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 159
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 160
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 161
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 162
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 163
# Expected returns of 21.38 with risk of 20.04 and SR = 0.82
#
# Iteration: 164
# Expected returns of 21.39 with risk of 20.05 and SR = 0.82
#
# Iteration: 165
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 166
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 167
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 168
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 169
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 170
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 171
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 172
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 173
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 174
# Expected returns of 21.39 with risk of 20.05 and SR = 0.82
#
# Iteration: 175
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 176
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 177
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 178
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 179
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 180
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 181
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 182
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 183
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 184
# Expected returns of 21.37 with risk of 20.02 and SR = 0.82
#
# Iteration: 185
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 186
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 187
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 188
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 189
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 190
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 191
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 192
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 193
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 194
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 195
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 196
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 197
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 198
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 199
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 200
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 201
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 202
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 203
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 204
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 205
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 206
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 207
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 208
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 209
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 210
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 211
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 212
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 213
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 214
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 215
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 216
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 217
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 218
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 219
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 220
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 221
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
# Iteration: 222
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 223
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 224
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 225
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 226
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 227
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 228
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 229
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 230
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 231
# Expected returns of 21.38 with risk of 20.03 and SR = 0.82
#
# Iteration: 232
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 233
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 234
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 235
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 236
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 237
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 238
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 239
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 240
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 241
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 242
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 243
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 244
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 245
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 246
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 247
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 248
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 249
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 250
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 251
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 252
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 253
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 254
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 255
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 256
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 257
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 258
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 259
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 260
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 261
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 262
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 263
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 264
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 265
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 266
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 267
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 268
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 269
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 270
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 271
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 272
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 273
# Expected returns of 21.4 with risk of 20.05 and SR = 0.82
#
# Iteration: 274
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 275
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 276
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 277
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 278
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 279
# Expected returns of 21.39 with risk of 20.03 and SR = 0.82
#
# Iteration: 280
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 281
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 282
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 283
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 284
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 285
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 286
# Expected returns of 21.4 with risk of 20.04 and SR = 0.82
#
# Iteration: 287
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 288
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 289
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 290
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 291
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 292
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 293
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 294
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 295
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 296
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 297
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 298
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 299
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
# Iteration: 300
# Expected returns of 21.39 with risk of 20.04 and SR = 0.82
#
#
#
# =====================================================
# Portfolio of stocks after all the iterations:
#
# APOLLO HOSPITALS ENTERPRISE LTD. : 0.03402312348781479
# ASIAN PAINTS LTD. : 0.033973110763886205
# BAJAJ FINANCE LTD. : 0.03575314770074794
# BHARAT PETROLEUM CORPN. LTD. : 0.010543324189975547
# BHARTI AIRTEL LTD. : 0.017324362795394038
# BRITANNIA INDUSTRIES LTD. : 0.012881092575511082
# CIPLA LTD. : 0.026213498049612805
# COAL INDIA LTD. : 0.00852251920071541
# DIVI'S LABORATORIES LTD. : 0.0370476648227836
# DR. REDDY'S LABORATORIES LTD. : 0.035763354712780186
# EICHER MOTORS LTD. : 0.004025419946880876
# GRASIM INDUSTRIES LTD. : 0.010568912119913135
# ADANI PORTS & SPECIAL ECONOMIC ZONE LTD. : 0.0174154744720647
# H C L TECHNOLOGIES LTD. : 0.020582253335870618
# H D F C BANK LTD. : 0.01221996112467607
# H D F C LIFE INSURANCE CO. LTD. : 0.027591362911709272
# HERO MOTOCORP LTD. : 0.010677287028473299
# HINDALCO INDUSTRIES LTD. : 0.013005185867329856
# HINDUSTAN UNILEVER LTD. : 0.03204185439312653
# HOUSING DEVELOPMENT FINANCE CORPN. LTD. : 0.021088012715260836
# I C I C I BANK LTD. : 0.026819609011792343
# I T C LTD. : 0.011990083106652666
# INDUSIND BANK LTD. : 0.008846238046209003
# INFOSYS LTD. : 0.026787627344934097
# J S W STEEL LTD. : 0.018678180497880004
# KOTAK MAHINDRA BANK LTD. : 0.03187013893405276
# ULTRATECH CEMENT LTD. : 0.017338169988737957
# LARSEN & TOUBRO LTD. : 0.013227696014898292
# MAHINDRA & MAHINDRA LTD. : 0.00930243980698987
# TECH MAHINDRA LTD. : 0.03362262700601318
# MARUTI SUZUKI INDIA LTD. : 0.010716490441223199
# N T P C LTD. : 0.008832928660220528
# NESTLE INDIA LTD. : 0.035693737218413776
# OIL & NATURAL GAS CORPN. LTD. : 0.008589990010125318
# TATA CONSULTANCY SERVICES LTD. : 0.02255579082928294
# POWER GRID CORPN. OF INDIA LTD. : 0.013560396345740196
# RELIANCE INDUSTRIES LTD. : 0.033624924829865274
# S B I LIFE INSURANCE CO. LTD. : 0.02185690940794377
# U P L LTD. : 0.009405811715064213
# SHREE CEMENT LTD. : 0.01887495378207358
# STATE BANK OF INDIA : 0.01061451630617229
# SUN PHARMACEUTICAL INDS. LTD. : 0.017787133590570076
# TATA MOTORS LTD. : 0.008362609857074047
# TATA STEEL LTD. : 0.011845369456567879
# TATA CONSUMER PRODUCTS LTD. : 0.031994008823361404
# TITAN COMPANY LTD. : 0.03196479565818826
# AXIS BANK LTD. : 0.017263773389869383
# WIPRO LTD. : 0.02501554264824353
# BAJAJ AUTO LTD. : 0.016469003458872623
# BAJAJ FINSERV LTD. : 0.02522758159844071
#
# Expected returns of 21.39 with risk of 20.04 and Sharpe Ratio of 0.82
# Wall time: 10h 16min 58s

# %%
# %%time

## Determine the Optimum portfolio using Heuristic Crossover

n=50 # Number of stocks = 6
pop_size=250 # initial population = 100

# Initial population
population = np.array([chromosome(n) for _ in range(pop_size)])

# Get initial elite population
elite = Select_elite_population(population)

iteration=0 
Expected_returns=10
Expected_risk=15

plotData1 = {
    "expReturns": [],
    "expRisk": [],
    "SharpeRatio": [] 
}

while (Expected_returns < 50 or Expected_risk > 5) and iteration <= 100:
    
    print('Iteration:',iteration)
    
    population = next_generation(250,elite,Heuristic_crossover)
    elite = Select_elite_population(population)
    
    Expected_returns=round((((1+mean_portfolio_return(elite[0]))**250)-1)*100,ndigits=1)
    Expected_risk=round(math.sqrt(var_portfolio_return(elite[0]))*math.sqrt(250)*100,ndigits=1)
    SR = (Expected_returns-5)/Expected_risk
    
    print('Expected returns of {} with risk of {} and SR = {}\n'.format(Expected_returns,Expected_risk,SR))
    plotData1['expReturns'].extend([Expected_returns])
    plotData1['expRisk'].extend([Expected_risk])
    plotData1['SharpeRatio'].extend([SR])
    
    iteration+=1

print('\n\n=====================================================\nPortfolio of stocks after all the iterations:\n')
[print(hist_stock_returns.columns[i],':',elite[0][i]) for i in list(range(50))]

print('\nExpected returns of {} with risk of {} and Sharpe Ratio of {}\n'.format(Expected_returns,Expected_risk, SR))

companies = []
wts = []
for i in list(range(50)):
    companies = companies + [hist_stock_returns.columns[i]]
    wts = wts + [elite[0][i]]

wtDf = pd.DataFrame(columns=['Company','Weight'])
wtDf.Company = companies
wtDf.Weight = wts
wtDf.to_csv('OptimizedWeightsJan2021-Jun2021_1.csv',index=False)
# Out:
# Iteration: 0
# Expected returns of 19.2 with risk of 21.6 and SR = 0.6574074074074073
#
# Iteration: 1
# Expected returns of 20.9 with risk of 22.0 and SR = 0.7227272727272727
#
# Iteration: 2
# Expected returns of 21.0 with risk of 22.1 and SR = 0.7239819004524887
#
# Iteration: 3
# Expected returns of 25.4 with risk of 24.3 and SR = 0.8395061728395061
#
# Iteration: 4
# Expected returns of 25.5 with risk of 22.0 and SR = 0.9318181818181818
#
# Iteration: 5
# Expected returns of 29.4 with risk of 21.9 and SR = 1.1141552511415524
#
# Iteration: 6
# Expected returns of 35.3 with risk of 26.6 and SR = 1.139097744360902
#
# Iteration: 7
# Expected returns of 48.3 with risk of 34.0 and SR = 1.2735294117647058
#
# Iteration: 8
# Expected returns of 53.8 with risk of 34.8 and SR = 1.4022988505747127
#
# Iteration: 9
# Expected returns of 47.0 with risk of 30.7 and SR = 1.3680781758957654
#
# Iteration: 10
# Expected returns of 59.0 with risk of 34.3 and SR = 1.5743440233236152
#
# Iteration: 11
# Expected returns of 73.6 with risk of 32.0 and SR = 2.14375
#
# Iteration: 12
# Expected returns of 96.0 with risk of 36.4 and SR = 2.5
#
# Iteration: 13
# Expected returns of 98.2 with risk of 36.8 and SR = 2.5326086956521743
#
# Iteration: 14
# Expected returns of 99.1 with risk of 36.6 and SR = 2.57103825136612
#
# Iteration: 15
# Expected returns of 107.2 with risk of 38.5 and SR = 2.6545454545454548
#
# Iteration: 16
# Expected returns of 137.5 with risk of 44.9 and SR = 2.951002227171492
#
# Iteration: 17
# Expected returns of 135.5 with risk of 44.6 and SR = 2.9260089686098656
#
# Iteration: 18
# Expected returns of 274.5 with risk of 62.9 and SR = 4.284578696343402
#
# Iteration: 19
# Expected returns of 287.6 with risk of 62.7 and SR = 4.507177033492823
#
# Iteration: 20
# Expected returns of 336.9 with risk of 69.3 and SR = 4.789321789321789
#
# Iteration: 21
# Expected returns of 228.4 with risk of 56.6 and SR = 3.9469964664310955
#
# Iteration: 22
# Expected returns of 536.8 with risk of 89.1 and SR = 5.968574635241302
#
# Iteration: 23
# Expected returns of 285.9 with risk of 59.1 and SR = 4.752961082910321
#
# Iteration: 24
# Expected returns of 314.0 with risk of 60.4 and SR = 5.1158940397351
#
# Iteration: 25
# Expected returns of 323.6 with risk of 60.0 and SR = 5.3100000000000005
#
# Iteration: 26
# Expected returns of 320.7 with risk of 59.8 and SR = 5.2792642140468224
#
# Iteration: 27
# Expected returns of 336.5 with risk of 60.8 and SR = 5.452302631578948
#
# Iteration: 28
# Expected returns of 321.1 with risk of 59.5 and SR = 5.312605042016807
#
# Iteration: 29
# Expected returns of 332.9 with risk of 60.8 and SR = 5.3930921052631575
#
# Iteration: 30
# Expected returns of 290.7 with risk of 57.2 and SR = 4.994755244755244
#
# Iteration: 31
# Expected returns of 291.7 with risk of 58.1 and SR = 4.93459552495697
#
# Iteration: 32
# Expected returns of 519.9 with risk of 76.3 and SR = 6.748361730013106
#
# Iteration: 33
# Expected returns of 556.3 with risk of 78.8 and SR = 6.996192893401015
#
# Iteration: 34
# Expected returns of 551.7 with risk of 78.8 and SR = 6.93781725888325
#
# Iteration: 35
# Expected returns of 584.8 with risk of 82.2 and SR = 7.053527980535279
#
# Iteration: 36
# Expected returns of 746.4 with risk of 91.7 and SR = 8.085059978189749
#
# Iteration: 37
# Expected returns of 299.9 with risk of 56.3 and SR = 5.238010657193605
#
# Iteration: 38
# Expected returns of 298.5 with risk of 55.8 and SR = 5.259856630824373
#
# Iteration: 39
# Expected returns of 289.7 with risk of 55.3 and SR = 5.1482820976491865
#
# Iteration: 40
# Expected returns of 288.6 with risk of 55.2 and SR = 5.13768115942029
#
# Iteration: 41
# Expected returns of 806.7 with risk of 89.5 and SR = 8.957541899441342
#
# Iteration: 42
# Expected returns of 626.1 with risk of 83.2 and SR = 7.465144230769231
#
# Iteration: 43
# Expected returns of 634.2 with risk of 83.2 and SR = 7.5625
#
# Iteration: 44
# Expected returns of 1016.3 with risk of 98.1 and SR = 10.308868501529052
#
# Iteration: 45
# Expected returns of 949.7 with risk of 96.6 and SR = 9.779503105590063
#
# Iteration: 46
# Expected returns of 919.3 with risk of 96.1 and SR = 9.514047866805411
#
# Iteration: 47
# Expected returns of 930.5 with risk of 93.9 and SR = 9.856230031948881
#
# Iteration: 48
# Expected returns of 921.3 with risk of 96.0 and SR = 9.544791666666667
#
# Iteration: 49
# Expected returns of 917.9 with risk of 95.0 and SR = 9.609473684210526
#
# Iteration: 50
# Expected returns of 2177.5 with risk of 129.0 and SR = 16.84108527131783
#
# Iteration: 51
# Expected returns of 2144.4 with risk of 128.1 and SR = 16.701014832162375
#
# Iteration: 52
# Expected returns of 912.2 with risk of 93.6 and SR = 9.692307692307693
#
# Iteration: 53
# Expected returns of 920.0 with risk of 93.7 and SR = 9.765208110992528
#
# Iteration: 54
# Expected returns of 5.550225678954363e+58 with risk of 7037.5 and SR = 7.886643948780623e+54
#
# Iteration: 55
# Expected returns of 8.299856371424707e+58 with risk of 6980.0 and SR = 1.1890911706912188e+55
#
# Iteration: 56
# Expected returns of 1.5538299094876925e+17 with risk of 1528.8 and SR = 101637225895322.64
#
# Iteration: 57
# Expected returns of 1.1977953168257968e+61 with risk of 7319.6 and SR = 1.6364218219927276e+57
#
# Iteration: 58
# Expected returns of 4.85098404413515e+58 with risk of 6931.4 and SR = 6.998563124527729e+54
#
# Iteration: 59
# Expected returns of 2.1296212466122656e+45 with risk of 4927.4 and SR = 4.321997902772792e+41
#
# Iteration: 60
# Expected returns of 1.841158789609288e+45 with risk of 4919.1 and SR = 3.7428773344906336e+41
#
# Iteration: 61
# Expected returns of 3.119306552047711e+45 with risk of 4930.3 and SR = 6.326808819032738e+41
#
# Iteration: 62
# Expected returns of 1.5502094716651742e+57 with risk of 6587.2 and SR = 2.3533663342014424e+53
#
# Iteration: 63
# Expected returns of 4.32950486408085e+44 with risk of 4742.8 and SR = 9.12858409395473e+40
#
# Iteration: 64
# Expected returns of 3.5201485288743156e+44 with risk of 4732.4 and SR = 7.438400238513895e+40
#
# Iteration: 65
# Expected returns of 7.848097133777327e+115 with risk of 18408.8 and SR = 4.2632312447184647e+111
#
# Iteration: 66
# Expected returns of 1.7330858390742136e+163 with risk of 33821.7 and SR = 5.124183110471128e+158
#
# Iteration: 67
# Expected returns of 1.1593322504163451e+177 with risk of 39872.7 and SR = 2.907584012159561e+172
#
# Iteration: 68
# Expected returns of 1.3688987862854558e+114 with risk of 18066.9 and SR = 7.57683269562269e+109
#
# Iteration: 69
# Expected returns of 1.1012640832751166e+94 with risk of 13269.7 and SR = 8.29908802214908e+89
#
# Iteration: 70
# Expected returns of 2.0973895783010285e+112 with risk of 17343.8 and SR = 1.2093022165275363e+108
#
# Iteration: 71
# Expected returns of 7.807653327293328e+112 with risk of 17376.1 and SR = 4.493328956033476e+108
#
# Iteration: 72
# Expected returns of 3.258483854244223e+115 with risk of 18292.2 and SR = 1.781351534667357e+111
#
# Iteration: 73
# Expected returns of 9.93879477733928e+115 with risk of 18412.9 and SR = 5.397734619391448e+111
#
# Iteration: 74
# Expected returns of 7.580386035130963e+296 with risk of 139243.1 and SR = 5.443994018469111e+291
#
# Iteration: 75
# Expected returns of 1.2526045221145526e+297 with risk of 139837.6 and SR = 8.957565934445046e+291
#
# Iteration: 76
# Expected returns of 3.2810398612483288e+289 with risk of 129411.2 and SR = 2.5353600470811868e+284
#
# Iteration: 77
# Expected returns of 5.621583339580456e+289 with risk of 128322.4 and SR = 4.380827774091239e+284
#
# Iteration: 78
# Expected returns of 4.0354192456640355e+284 with risk of 119399.5 and SR = 3.379762265054741e+279
#
# Iteration: 79
# Expected returns of 3.2810342668485316e+250 with risk of 85419.5 and SR = 3.841083437445234e+245
#
# Iteration: 80
# Expected returns of 2.8309404994864764e+281 with risk of 117254.8 and SR = 2.41434934816014e+276
#
# Iteration: 81
# Expected returns of 1.7452927370936557e+283 with risk of 118090.2 and SR = 1.4779319004402193e+278
#
# Iteration: 82
# Expected returns of 9.377306872786499e+306 with risk of 148583.2 and SR = 6.311148819507521e+301
#
# Iteration: 83
# Expected returns of 1.1550969484047406e+307 with risk of 148690.7 and SR = 7.768454573182724e+301
#
# Iteration: 84
# Expected returns of 2.6290707520265182e+284 with risk of 118612.5 and SR = 2.2165208152821315e+279
#
# Iteration: 85
# Expected returns of 1.0195983783171707e+285 with risk of 117956.9 and SR = 8.643821415425217e+279
#
# Iteration: 86
# Expected returns of 4.24330881040899e+283 with risk of 117834.5 and SR = 3.601075075982832e+278
#
# Iteration: 87
# Expected returns of 5.063579320322797e+290 with risk of 126572.0 and SR = 4.000552507918653e+285
#
# Iteration: 88
# Expected returns of 1.1601087832354869e+275 with risk of 107425.4 and SR = 1.0799203756611444e+270
#
# Iteration: 89
# Expected returns of 3.3374030399503463e+271 with risk of 102255.5 and SR = 3.263788294957578e+266
#
# Iteration: 90
# Expected returns of 6.987151212276958e+270 with risk of 102235.1 and SR = 6.834395635429474e+265
#
# Iteration: 91
# Expected returns of 7.249035022046557e+270 with risk of 102286.2 and SR = 7.087011759207554e+265
#
# Iteration: 92
# Expected returns of 1.8874263258150197e+270 with risk of 102089.0 and SR = 1.848804793675146e+265
#
# Iteration: 93
# Expected returns of 6.942122106628856e+270 with risk of 102040.0 and SR = 6.803334091169007e+265
#
# Iteration: 94
# Expected returns of 1.1778812918921689e+269 with risk of 99839.2 and SR = 1.1797783755200051e+264
#
# Iteration: 95
# Expected returns of 9.067849608159006e+269 with risk of 101376.9 and SR = 8.94469016921903e+264
#
# Iteration: 96
# Expected returns of 5.876865852243486e+263 with risk of 94226.7 and SR = 6.236943299769052e+258
#
# Iteration: 97
# Expected returns of 6.373478920107495e+271 with risk of 102270.2 and SR = 6.232000054862018e+266
#
# Iteration: 98
# Expected returns of 7.621059414298541e+271 with risk of 102597.7 and SR = 7.428099669191942e+266
#
# Iteration: 99
# Expected returns of 1.2372544316299732e+273 with risk of 104471.7 and SR = 1.1842962559525433e+268
#
# Iteration: 100
# Expected returns of 4.367890464521987e+271 with risk of 102785.2 and SR = 4.249532485729451e+266
#
#
#
# =====================================================
# Portfolio of stocks after all the iterations:
#
# APOLLO HOSPITALS ENTERPRISE LTD. : 229.56268205926574
# ASIAN PAINTS LTD. : 555.9296622684757
# BAJAJ FINANCE LTD. : 395.98435638915265
# BHARAT PETROLEUM CORPN. LTD. : -119.59787913214683
# BHARTI AIRTEL LTD. : 104.2728533081062
# BRITANNIA INDUSTRIES LTD. : -89.55948279226934
# CIPLA LTD. : 17.643292012745526
# COAL INDIA LTD. : -518.5963053669701
# DIVI'S LABORATORIES LTD. : 1382.4744295369198
# DR. REDDY'S LABORATORIES LTD. : 183.5408955773903
# EICHER MOTORS LTD. : -397.83799079479917
# GRASIM INDUSTRIES LTD. : -572.8990685480918
# ADANI PORTS & SPECIAL ECONOMIC ZONE LTD. : -175.0068262921802
# H C L TECHNOLOGIES LTD. : 2.9524736618129914
# H D F C BANK LTD. : -269.4012133943965
# H D F C LIFE INSURANCE CO. LTD. : 20.012802228900547
# HERO MOTOCORP LTD. : -206.42269023117552
# HINDALCO INDUSTRIES LTD. : 69.66451493364559
# HINDUSTAN UNILEVER LTD. : 328.2166618894053
# HOUSING DEVELOPMENT FINANCE CORPN. LTD. : 190.60211608599258
# I C I C I BANK LTD. : 595.9726601684415
# I T C LTD. : -593.7995320340159
# INDUSIND BANK LTD. : -41.55577054920492
# INFOSYS LTD. : 335.9086775891354
# J S W STEEL LTD. : 172.04405446279597
# KOTAK MAHINDRA BANK LTD. : 106.51874233649693
# ULTRATECH CEMENT LTD. : 13.560175277797303
# LARSEN & TOUBRO LTD. : 6.176844863429656
# MAHINDRA & MAHINDRA LTD. : 232.08589184109297
# TECH MAHINDRA LTD. : -9.13768546883848
# MARUTI SUZUKI INDIA LTD. : -625.5050589101238
# N T P C LTD. : -2159.8447769869285
# NESTLE INDIA LTD. : 289.9173503992299
# OIL & NATURAL GAS CORPN. LTD. : -51.905364287604066
# TATA CONSULTANCY SERVICES LTD. : -124.61104573234816
# POWER GRID CORPN. OF INDIA LTD. : 201.88927059341552
# RELIANCE INDUSTRIES LTD. : 159.63001727520853
# S B I LIFE INSURANCE CO. LTD. : -202.0583749762038
# U P L LTD. : -565.5669874437352
# SHREE CEMENT LTD. : 682.8021624829685
# STATE BANK OF INDIA : -253.0007646839763
# SUN PHARMACEUTICAL INDS. LTD. : -397.4145575405536
# TATA MOTORS LTD. : -395.60312258099077
# TATA STEEL LTD. : 115.0362059819519
# TATA CONSUMER PRODUCTS LTD. : 649.2884904992545
# TITAN COMPANY LTD. : 534.3707069576724
# AXIS BANK LTD. : 131.6134420358716
# WIPRO LTD. : 353.7359251196366
# BAJAJ AUTO LTD. : -404.8140952498365
# BAJAJ FINSERV LTD. : 113.7312351601781
#
# Expected returns of 4.367890464521987e+271 with risk of 102785.2 and Sharpe Ratio of 4.249532485729451e+266
#
# Wall time: 8h 3min 20s

# %%
pd.DataFrame(plotData).to_csv('C1Results.csv')
pd.DataFrame(plotData1).to_csv('C1Results_Heuristic.csv')
